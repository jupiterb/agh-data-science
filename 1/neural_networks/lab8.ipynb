# %%
import numpy as np
import matplotlib.pyplot as plt
import time
# import mkl

# mkl.set_num_threads(2)
np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix, axis=1):
    return np.concatenate((matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis)

def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def randn(*dims):
    return np.random.randn(*dims).astype(np.float32)

def chunks(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def as_matrix(vector):
    return np.reshape(vector, (-1, 1))

def one_hot_encode(labels):
    one_hot = zeros(labels.shape[0], np.max(labels) + 1) 
    one_hot[np.arange(labels.shape[0]), labels] = 1
    return one_hot.astype(np.float32)

def classify(mlp, batch):
    probabilities = forward_pass(mlp, batch, False)
    return np.argmax(probabilities, axis=1)

def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]
    
    space_between_tiles = 2
    img_matrix = np.empty(shape=(rows_count * (tile_height + space_between_tiles) - space_between_tiles,  
                                 cols_count * (tile_width + space_between_tiles) - space_between_tiles))
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0:x_0 + tile_height, y_0:y_0 + tile_width] = (examples[r, c] - ex_min) / (ex_max - ex_min)
    
    plt.matshow(img_matrix, cmap='gray', interpolation='none')
    plt.axis('off')
    plt.show()

def draw_rbm_filters(rbm):
    filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
    tiles(filters)

def draw_layer_filters(layer):
    filters = np.reshape(layer.W[:-1].T, newshape=(8, -1, 28, 28))
    tiles(filters)

# %% [markdown]
# ### Activation functions

# %%
def sigmoid(batch, stochastic=False):
    activations = 1.0 / (1.0 + np.exp(-batch))
    if stochastic:
        return activations > rand(*activations.shape).astype(np.float32)
    else:
        return activations

def sigmoid_derivative(batch):
    s = sigmoid(batch)
    return s * (1.0 - s)

def softmax(batch):
    negative_batch = batch - np.max(batch, axis=-1, keepdims=True)
    numerator = np.exp(negative_batch)
    denominator = np.sum(numerator, axis=-1, keepdims=True)
    return numerator / denominator

# %% [markdown]
# # MNIST dataset

# %%
import mnist
digits = np.reshape(mnist.train_images()[:12*24], newshape=(12, 24, 28, 28))
tiles(digits)

# %% [markdown]
# # ReLU and Max-Norm regularization

# %%
def relu(batch, stochastic=False):
    activations = np.maximum(0, batch)
    if stochastic:
        return activations + (activations > 0) * rand(*activations.shape).astype(np.float32)
    else:
        return activations

def relu_derivative(batch):
    return (batch > 0).astype(np.float32)

# %%
def limit_weights(weights, limit):
    importance = ones(*weights.shape)
    norms = np.linalg.norm(weights, axis=0)
    importance[:, norms > limit] = limit / norms[norms > limit]
    return weights * importance

# %% [markdown]
# # RBM & DBN training

# %%
class Rbm:
    def __init__(self, visible_size, hidden_size, visible_act_func, hidden_act_func, 
                 learning_rate, momentum, weight_limit):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        
        self.visible_act_func = visible_act_func
        self.hidden_act_func = hidden_act_func
        
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.weight_limit = weight_limit
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size+1)).astype(np.float32)
        self.W[:, -1] = 0.0
        self.W[-1, :] = 0.0
        self.M = zeros(self.visible_size+1, self.hidden_size+1)

# %%
def cdk(rbm, minibatch, k=1):
    observations_count = minibatch.shape[0]

    positive_visible = minibatch
    negative_visible = append_ones(zeros(observations_count, rbm.visible_size))

    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_hidden = append_ones(zeros(observations_count, rbm.hidden_size))

    z = minibatch @ rbm.W[:, :-1]
    positive_hidden[:, :-1] = rbm.hidden_act_func(z)
    negative_hidden[:, :-1] = rbm.hidden_act_func(z, stochastic=True)

    for cd_i in range(k):
        negative_visible[:, :-1] = rbm.visible_act_func(negative_hidden @ rbm.W[:-1, :].T,
                                                        stochastic=True)
        z = negative_visible @ rbm.W[:, :-1]
        if cd_i < (k - 1):
            negative_hidden[:, :-1] = rbm.hidden_act_func(z, stochastic=True)
        else:
            negative_hidden[:, :-1] = rbm.hidden_act_func(z)

    rbm.M *= rbm.momentum
    rbm.M += (rbm.learning_rate / observations_count) * positive_visible.T @ positive_hidden
    rbm.M -= (rbm.learning_rate / observations_count) * negative_visible.T @ negative_hidden

    rbm.W += rbm.M;
    
    if rbm.weight_limit > 0.0:
        rbm.W[:-1, :-1] = limit_weights(rbm.W[:-1, :-1], rbm.weight_limit)

def reconstuction_error(rbm, minibatch):
    observations_count = minibatch.shape[0]
    visible = zeros(observations_count, rbm.visible_size)
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    hidden[:, :-1] =  rbm.hidden_act_func(minibatch @ rbm.W[:, :-1], stochastic=True)
    visible = rbm.visible_act_func(hidden @ np.transpose(rbm.W[:-1, :]))
    
    error = minibatch[:, :-1] - visible
    error = np.sum(np.square(error)) / observations_count
    
    return error

# %%
def propagate_up(dbn, layers_count, visible):
    for i in range(layers_count):
        visible = append_ones(sigmoid(visible @ dbn[i].W[:, :-1]))
    return visible

def propagate_down(dbn, layers_count, hidden):
    for i in reversed(range(layers_count)):
        hidden = append_ones(sigmoid(hidden @ np.transpose(dbn[i].W[:-1, :])))
    return hidden

def dbn_reconstuction_error(dbn, layer_idx, minibatch):
    propagated = propagate_up(dbn, layer_idx, minibatch)
    return reconstuction_error(dbn[layer_idx], propagated)

def train_dbn_layer(dbn, layer_idx, dataset, batch_size):
    dataset = propagate_up(dbn, layer_idx, dataset)
    
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(dbn[layer_idx], batch)
        if batch_idx % round(batches_limit / 40) == 0: print("#", end="")
            
def run_dbn_training(dbn, dataset, monitoring_set, batch_size, epochs_count, target_momentum=0.9):
    for layer_idx in range(len(dbn)):
        print("\nLearning layer {}".format(layer_idx+1))

        for epoch in range(epochs_count):
            print("Epoch {}:".format(epoch+1),  end="\t")

            if epoch == 5:
                dbn[layer_idx].momentum = target_momentum

            start_time = time.time()
            train_dbn_layer(dbn, layer_idx, dataset, batch_size)
            elapsed = time.time() - start_time

            error = dbn_reconstuction_error(dbn, layer_idx, monitoring_set)
            print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))

# %% [markdown]
# # MLP training

# %%
class Layer:
    def __init__(self, visible_size, hidden_size, activation_fun, d_activation_fun, 
                 learning_rate, momentum, weight_limit):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        
        self.activation_fun = activation_fun
        self.d_activation_fun = d_activation_fun
                
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.weight_limit = weight_limit
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size)).astype(np.float32)
        self.W[-1, :] = 0.0
        
        self.activations = None
        self.d_activations = None
        self.deltas = None

        self.M = zeros(self.visible_size+1, self.hidden_size)

# %% [markdown]
# ### Forward pass

# %%
def forward_pass(mlp, batch, compute_derivatives):
    visible = batch
    
    for layer_idx, layer in enumerate(mlp):
        z = visible @ layer.W
        layer.activations = append_ones(layer.activation_fun(z))
        
        if compute_derivatives and (layer_idx < len(mlp) - 1):
            layer.d_activations = layer.d_activation_fun(z)
        
        visible = layer.activations
        
    return visible[:, :-1]

# %% [markdown]
# ### Error backpropagation

# %%
def error_backpropagate(mlp, batch):
    observations_count = batch.shape[0]
    
    for layer_idx, layer in reversed(list(enumerate(mlp))):
        if layer_idx > 0:
            prev_layer = mlp[layer_idx - 1]
            visible = prev_layer.activations
            
            prev_layer.deltas = (layer.deltas @ layer.W[:-1].T) * prev_layer.d_activations
        else:
            visible = batch
        
        gradient = (visible.T @ layer.deltas) / observations_count
        layer.M = layer.momentum * layer.M - layer.learning_rate * gradient

        layer.W += layer.M
        
        if layer.weight_limit > 0.0:
            layer.W[:-1, :] = limit_weights(layer.W[:-1, :], layer.weight_limit)

# %% [markdown]
# ### Training procedure

# %%
def train_mlp(mlp, dataset, labels, batch_size):
    batches_limit = dataset.shape[0] / batch_size
    
    batched_data = chunks(dataset, batch_size)
    batched_labels = chunks(labels, batch_size)
    
    for batch_idx, (batch, batch_labels) in enumerate(zip(batched_data, batched_labels)):
        # Forward pass: compute activatations and derivatives of activations
        y = forward_pass(mlp, batch, True)
        
        mlp[-1].deltas = y - batch_labels
        
        # Once softmax deltas are set, we may backpropagate errors
        error_backpropagate(mlp, batch)
        
        if batch_idx % round(batches_limit / 40) == 0: print("#", end="")

# %%
def run_mlp_training(mlp, train_set, train_labels, validation_set, validation_labels,
                     batch_size, epochs_count, target_momentum=0.95):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch+1),  end="\t")
        
        if epoch == 5:
            for layer in mlp: layer.momentum = target_momentum
        
        start_time = time.time()
        train_mlp(mlp, train_set, train_labels, batch_size)
        elapsed = time.time() - start_time

        predictions = classify(mlp, validation_set)
        accuracy = 100.0 * np.sum(predictions == validation_labels) / predictions.shape[0]
        print("\telapsed: {0:>2.2f}s, accuracy: {1:>2.2f}".format(elapsed, accuracy))

    print("Training finished!")

# %% [markdown]
# #  Initializing MLP with DBN weights
#
# Implement initialization of MLP weights (and biases) using weights (and biases) from the DBN layers.
#
# Make sure that the MLP weights (and biases) are **copies** of the DBN weights (and biases). You can use ```np.copy(...)``` function to copy the weights (simple assignment will make a view instead of a copy).

# %%
def initialize_mlp(mlp, dbn):
    for layer_idx in range(len(dbn)):
        mlp[layer_idx].W = np.copy(dbn[layer_idx].W[:, :-1])

# %% [markdown]
# # MNIST digits classification

# %%
DATASET_SIZE = 10000 # 60000 for whole dataset
DIGIT_SIZE = 28

##### Train set #####

mnist_train_images = mnist.train_images().astype(np.float32) / 255.0
mnist_train_labels = mnist.train_labels()

order = np.random.permutation(len(mnist_train_images))
mnist_train_images = mnist_train_images[order]
mnist_train_labels = mnist_train_labels[order]

mnist_train_images = np.reshape(mnist_train_images[:DATASET_SIZE],
                                newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
mnist_train_images = append_ones(mnist_train_images)

mnist_train_labels = mnist_train_labels[:DATASET_SIZE]
mnist_train_labels = one_hot_encode(mnist_train_labels)

monitoring_set_indeces = np.random.choice(mnist_train_images.shape[0], 512, replace=False)
monitoring_set = mnist_train_images[monitoring_set_indeces]

##### Test set #####

mnist_test_images = mnist.test_images().astype(np.float32) / 255.0
mnist_test_images = np.reshape(mnist_test_images, newshape=(-1, DIGIT_SIZE*DIGIT_SIZE))
mnist_test_images = append_ones(mnist_test_images)

mnist_test_labels = mnist.test_labels()

# %%
VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE
HIDDEN_LAYER_SIZE = 256

BATCH_SIZE = 128
EPOCHS_COUNT = 50

MLP_LEARNING_RATE = 0.03
SOFTMAX_LEARNING_RATE = 0.15
RBM_LEARNING_RATE = 0.003
MOMENTUM = 0.5

# %% [markdown]
# ### Plain vs pretrained comparison

# %%
from IPython.core.display import HTML

def compare_pretraining_results(mlp, dbn,
                                train_set, train_labels,
                                validation_set, validation_labels,
                                monitoring_set,
                                batch_size, epochs_count):
    for layer in mlp:
        layer.reset()

    display(HTML('<h3>Plain MLP training</h3>'))
    run_mlp_training(mlp,
                     train_set, train_labels,
                     validation_set, validation_labels,
                     batch_size, epochs_count)
    
    display(HTML('<h3>Input layer filters in the plain MLP</h3>'))
    draw_layer_filters(mlp[0])
    
    display(HTML('<h3>Largest norms of weight-vectors in the plain MLP layers</h3>'))
    for i, layer in enumerate(mlp):
        max_norm = np.max(np.linalg.norm(layer.W[:-1, :], axis=0))
        print('\tlayer {0}: {1:.2f}'.format(i+1, max_norm))
    
    display(HTML('<h3>DBN training</h3>'))
    run_dbn_training(dbn, train_set, monitoring_set, batch_size, epochs_count)
    
    for layer in mlp:
        layer.reset()
    
    initialize_mlp(mlp, dbn)
    
    display(HTML('<h3>Finetuning pretrained MLP</h3>'))
    run_mlp_training(mlp,
                     train_set, train_labels,
                     validation_set, validation_labels,
                     batch_size, epochs_count)
    
    display(HTML('<h3>First layer filters in the DBN</h3>'))
    draw_rbm_filters(dbn[0])
    
    display(HTML('<h3>Input layer filters in the pretrained & finetuned MLP</h3>'))
    draw_layer_filters(mlp[0])

    display(HTML('<h3>Largest norms of weight-vectors in the finetuned MLP layers</h3>'))
    for i, layer in enumerate(mlp):
        max_norm = np.max(np.linalg.norm(layer.W[:-1, :], axis=0))
        print('\tlayer {0}: {1:.2f}'.format(i+1, max_norm))

# %% [markdown]
# ### Shallow ReLU network

# %%
shallow_mlp = [
    Layer(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, MLP_LEARNING_RATE, MOMENTUM,
          weight_limit=2.0),
    Layer(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, MLP_LEARNING_RATE, MOMENTUM,
          weight_limit=1.0),
    Layer(HIDDEN_LAYER_SIZE, 10, softmax, None, SOFTMAX_LEARNING_RATE, MOMENTUM,
          weight_limit=4.0)
]

shallow_dbn = [
    Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, sigmoid, relu, RBM_LEARNING_RATE, MOMENTUM,
        weight_limit=2.0),
    Rbm(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu, RBM_LEARNING_RATE, MOMENTUM,
        weight_limit=1.0)
]

compare_pretraining_results(shallow_mlp, shallow_dbn,
                            mnist_train_images, mnist_train_labels,
                            mnist_test_images, mnist_test_labels,
                            monitoring_set,
                            BATCH_SIZE, EPOCHS_COUNT)
# Out:
# <h3>Plain MLP training</h3>
# Epoch 1:	########################################	elapsed: 1.00s, accuracy: 11.35
# Epoch 2:	########################################	elapsed: 0.98s, accuracy: 31.54
# Epoch 3:	########################################	elapsed: 0.88s, accuracy: 65.26
# Epoch 4:	########################################	elapsed: 0.75s, accuracy: 74.15
# Epoch 5:	########################################	elapsed: 0.59s, accuracy: 80.37
# Epoch 6:	########################################	elapsed: 0.66s, accuracy: 89.79
# Epoch 7:	########################################	elapsed: 0.67s, accuracy: 92.34
# Epoch 8:	########################################	elapsed: 0.52s, accuracy: 93.00
# Epoch 9:	########################################	elapsed: 0.49s, accuracy: 94.01
# Epoch 10:	########################################	elapsed: 0.53s, accuracy: 94.83
# Epoch 11:	########################################	elapsed: 0.51s, accuracy: 93.75
# Epoch 12:	########################################	elapsed: 0.79s, accuracy: 95.26
# Epoch 13:	########################################	elapsed: 0.69s, accuracy: 94.27
# Epoch 14:	########################################	elapsed: 0.61s, accuracy: 94.84
# Epoch 15:	########################################	elapsed: 0.56s, accuracy: 95.57
# Epoch 16:	########################################	elapsed: 0.56s, accuracy: 95.74
# Epoch 17:	########################################	elapsed: 0.57s, accuracy: 95.49
# Epoch 18:	########################################	elapsed: 0.59s, accuracy: 96.07
# Epoch 19:	########################################	elapsed: 0.63s, accuracy: 95.23
# Epoch 20:	########################################	elapsed: 0.67s, accuracy: 95.25
# Epoch 21:	########################################	elapsed: 0.62s, accuracy: 95.28
# Epoch 22:	########################################	elapsed: 0.67s, accuracy: 95.53
# Epoch 23:	########################################	elapsed: 0.57s, accuracy: 96.06
# Epoch 24:	########################################	elapsed: 0.57s, accuracy: 96.06
# Epoch 25:	########################################	elapsed: 0.76s, accuracy: 96.33
# Epoch 26:	########################################	elapsed: 0.78s, accuracy: 96.36
# Epoch 27:	########################################	elapsed: 0.90s, accuracy: 96.41
# Epoch 28:	########################################	elapsed: 0.92s, accuracy: 96.37
# Epoch 29:	########################################	elapsed: 0.79s, accuracy: 96.37
# Epoch 30:	########################################	elapsed: 0.92s, accuracy: 96.40
# Epoch 31:	########################################	elapsed: 0.93s, accuracy: 96.40
# Epoch 32:	########################################	elapsed: 0.77s, accuracy: 96.39
# Epoch 33:	########################################	elapsed: 0.73s, accuracy: 96.40
# Epoch 34:	########################################	elapsed: 0.93s, accuracy: 96.41
# Epoch 35:	########################################	elapsed: 0.86s, accuracy: 96.42
# Epoch 36:	########################################	elapsed: 0.90s, accuracy: 96.42
# Epoch 37:	########################################	elapsed: 0.63s, accuracy: 96.44
# Epoch 38:	########################################	elapsed: 0.63s, accuracy: 96.46
# Epoch 39:	########################################	elapsed: 0.77s, accuracy: 96.46
# Epoch 40:	########################################	elapsed: 0.71s, accuracy: 96.48
# Epoch 41:	########################################	elapsed: 0.57s, accuracy: 96.49
# Epoch 42:	########################################	elapsed: 0.60s, accuracy: 96.48
# Epoch 43:	########################################	elapsed: 0.85s, accuracy: 96.47
# Epoch 44:	########################################	elapsed: 0.77s, accuracy: 96.47
# Epoch 45:	########################################	elapsed: 0.65s, accuracy: 96.47
# Epoch 46:	########################################	elapsed: 0.65s, accuracy: 96.47
# Epoch 47:	########################################	elapsed: 0.58s, accuracy: 96.48
# Epoch 48:	########################################	elapsed: 0.57s, accuracy: 96.47
# Epoch 49:	########################################	elapsed: 0.56s, accuracy: 96.47
# Epoch 50:	########################################	elapsed: 0.84s, accuracy: 96.47
# Training finished!
# <h3>Input layer filters in the plain MLP</h3>
# <h3>Largest norms of weight-vectors in the plain MLP layers</h3>
# 	layer 1: 1.75
# 	layer 2: 1.00
# 	layer 3: 4.00
# <h3>DBN training</h3>
# Learning layer 1
# Epoch 1:	########################################	elapsed: 0.95s, reconstruction error: 73.47
# Epoch 2:	########################################	elapsed: 0.81s, reconstruction error: 53.08
# Epoch 3:	########################################	elapsed: 0.76s, reconstruction error: 41.49
# Epoch 4:	########################################	elapsed: 0.67s, reconstruction error: 35.55
# Epoch 5:	########################################	elapsed: 0.68s, reconstruction error: 31.84
# Epoch 6:	########################################	elapsed: 0.66s, reconstruction error: 23.82
# Epoch 7:	########################################	elapsed: 0.66s, reconstruction error: 19.67
# Epoch 8:	########################################	elapsed: 0.67s, reconstruction error: 17.13
# Epoch 9:	########################################	elapsed: 0.66s, reconstruction error: 15.40
# Epoch 10:	########################################	elapsed: 0.66s, reconstruction error: 14.03
# Epoch 11:	########################################	elapsed: 0.73s, reconstruction error: 13.04
# Epoch 12:	########################################	elapsed: 0.73s, reconstruction error: 12.17
# Epoch 13:	########################################	elapsed: 0.68s, reconstruction error: 11.43
# Epoch 14:	########################################	elapsed: 0.68s, reconstruction error: 10.80
# Epoch 15:	########################################	elapsed: 0.67s, reconstruction error: 10.24
# Epoch 16:	########################################	elapsed: 0.69s, reconstruction error: 9.77
# Epoch 17:	########################################	elapsed: 0.71s, reconstruction error: 9.28
# Epoch 18:	########################################	elapsed: 0.71s, reconstruction error: 8.93
# Epoch 19:	########################################	elapsed: 0.70s, reconstruction error: 8.61
# Epoch 20:	########################################	elapsed: 0.72s, reconstruction error: 8.29
# Epoch 21:	########################################	elapsed: 0.80s, reconstruction error: 8.00
# Epoch 22:	########################################	elapsed: 0.80s, reconstruction error: 7.75
# Epoch 23:	########################################	elapsed: 0.80s, reconstruction error: 7.59
# Epoch 24:	########################################	elapsed: 0.84s, reconstruction error: 7.39
# Epoch 25:	########################################	elapsed: 0.92s, reconstruction error: 7.19
# Epoch 26:	########################################	elapsed: 0.94s, reconstruction error: 7.09
# Epoch 27:	########################################	elapsed: 0.79s, reconstruction error: 6.90
# Epoch 28:	########################################	elapsed: 0.76s, reconstruction error: 6.84
# Epoch 29:	########################################	elapsed: 0.71s, reconstruction error: 6.75
# Epoch 30:	########################################	elapsed: 0.78s, reconstruction error: 6.64
# Epoch 31:	########################################	elapsed: 0.72s, reconstruction error: 6.55
# Epoch 32:	########################################	elapsed: 0.73s, reconstruction error: 6.45
# Epoch 33:	########################################	elapsed: 0.72s, reconstruction error: 6.40
# Epoch 34:	########################################	elapsed: 0.81s, reconstruction error: 6.30
# Epoch 35:	########################################	elapsed: 0.79s, reconstruction error: 6.28
# Epoch 36:	########################################	elapsed: 0.77s, reconstruction error: 6.20
# Epoch 37:	########################################	elapsed: 0.91s, reconstruction error: 6.16
# Epoch 38:	########################################	elapsed: 0.87s, reconstruction error: 6.14
# Epoch 39:	########################################	elapsed: 0.85s, reconstruction error: 6.05
# Epoch 40:	########################################	elapsed: 0.81s, reconstruction error: 6.01
# Epoch 41:	########################################	elapsed: 0.75s, reconstruction error: 6.06
# Epoch 42:	########################################	elapsed: 0.76s, reconstruction error: 5.96
# Epoch 43:	########################################	elapsed: 0.80s, reconstruction error: 5.91
# Epoch 44:	########################################	elapsed: 0.75s, reconstruction error: 5.86
# Epoch 45:	########################################	elapsed: 0.75s, reconstruction error: 5.87
# Epoch 46:	########################################	elapsed: 0.77s, reconstruction error: 5.83
# Epoch 47:	########################################	elapsed: 0.75s, reconstruction error: 5.80
# Epoch 48:	########################################	elapsed: 0.75s, reconstruction error: 5.79
# Epoch 49:	########################################	elapsed: 0.75s, reconstruction error: 5.75
# Epoch 50:	########################################	elapsed: 0.78s, reconstruction error: 5.72
#
# Learning layer 2
# Epoch 1:	########################################	elapsed: 0.55s, reconstruction error: 56.24
# Epoch 2:	########################################	elapsed: 0.58s, reconstruction error: 55.58
# Epoch 3:	########################################	elapsed: 0.59s, reconstruction error: 53.92
# Epoch 4:	########################################	elapsed: 0.53s, reconstruction error: 51.60
# Epoch 5:	########################################	elapsed: 0.61s, reconstruction error: 50.62
# Epoch 6:	########################################	elapsed: 0.59s, reconstruction error: 48.20
# Epoch 7:	########################################	elapsed: 0.48s, reconstruction error: 47.48
# Epoch 8:	########################################	elapsed: 0.45s, reconstruction error: 46.36
# Epoch 9:	########################################	elapsed: 0.49s, reconstruction error: 46.28
# Epoch 10:	########################################	elapsed: 0.39s, reconstruction error: 45.80
# Epoch 11:	########################################	elapsed: 0.51s, reconstruction error: 45.11
# Epoch 12:	########################################	elapsed: 0.52s, reconstruction error: 44.65
# Epoch 13:	########################################	elapsed: 0.57s, reconstruction error: 45.10
# Epoch 14:	########################################	elapsed: 0.57s, reconstruction error: 44.78
# Epoch 15:	########################################	elapsed: 0.56s, reconstruction error: 44.66
# Epoch 16:	########################################	elapsed: 0.58s, reconstruction error: 44.89
# Epoch 17:	########################################	elapsed: 0.63s, reconstruction error: 44.46
# Epoch 18:	########################################	elapsed: 0.69s, reconstruction error: 44.51
# Epoch 19:	########################################	elapsed: 0.58s, reconstruction error: 44.28
# Epoch 20:	########################################	elapsed: 0.55s, reconstruction error: 44.47
# Epoch 21:	########################################	elapsed: 0.57s, reconstruction error: 44.25
# Epoch 22:	########################################	elapsed: 0.65s, reconstruction error: 44.63
# Epoch 23:	########################################	elapsed: 0.66s, reconstruction error: 43.98
# Epoch 24:	########################################	elapsed: 0.66s, reconstruction error: 44.31
# Epoch 25:	########################################	elapsed: 0.63s, reconstruction error: 44.27
# Epoch 26:	########################################	elapsed: 0.55s, reconstruction error: 43.93
# Epoch 27:	########################################	elapsed: 0.51s, reconstruction error: 44.15
# Epoch 28:	########################################	elapsed: 0.53s, reconstruction error: 43.90
# Epoch 29:	########################################	elapsed: 0.55s, reconstruction error: 44.20
# Epoch 30:	########################################	elapsed: 0.63s, reconstruction error: 44.04
# Epoch 31:	########################################	elapsed: 0.57s, reconstruction error: 44.04
# Epoch 32:	########################################	elapsed: 0.58s, reconstruction error: 44.13
# Epoch 33:	########################################	elapsed: 0.57s, reconstruction error: 44.18
# Epoch 34:	########################################	elapsed: 0.62s, reconstruction error: 43.82
# Epoch 35:	########################################	elapsed: 0.69s, reconstruction error: 43.99
# Epoch 36:	########################################	elapsed: 0.59s, reconstruction error: 43.99
# Epoch 37:	########################################	elapsed: 0.63s, reconstruction error: 44.08
# Epoch 38:	########################################	elapsed: 0.63s, reconstruction error: 43.95
# Epoch 39:	########################################	elapsed: 0.61s, reconstruction error: 44.10
# Epoch 40:	########################################	elapsed: 0.63s, reconstruction error: 44.06
# Epoch 41:	########################################	elapsed: 0.54s, reconstruction error: 44.08
# Epoch 42:	########################################	elapsed: 0.52s, reconstruction error: 44.15
# Epoch 43:	########################################	elapsed: 0.50s, reconstruction error: 44.04
# Epoch 44:	########################################	elapsed: 0.40s, reconstruction error: 43.92
# Epoch 45:	########################################	elapsed: 0.47s, reconstruction error: 43.98
# Epoch 46:	########################################	elapsed: 0.62s, reconstruction error: 43.80
# Epoch 47:	########################################	elapsed: 0.56s, reconstruction error: 43.95
# Epoch 48:	########################################	elapsed: 0.64s, reconstruction error: 43.62
# Epoch 49:	########################################	elapsed: 0.63s, reconstruction error: 44.18
# Epoch 50:	########################################	elapsed: 0.55s, reconstruction error: 43.92
# <h3>Finetuning pretrained MLP</h3>
# Epoch 1:	########################################	elapsed: 0.83s, accuracy: 93.44
# Epoch 2:	########################################	elapsed: 0.62s, accuracy: 94.95
# Epoch 3:	########################################	elapsed: 0.71s, accuracy: 94.89
# Epoch 4:	########################################	elapsed: 0.60s, accuracy: 96.11
# Epoch 5:	########################################	elapsed: 0.60s, accuracy: 95.54
# Epoch 6:	########################################	elapsed: 0.61s, accuracy: 96.10
# Epoch 7:	########################################	elapsed: 0.59s, accuracy: 96.41
# Epoch 8:	########################################	elapsed: 0.76s, accuracy: 96.80
# Epoch 9:	########################################	elapsed: 0.58s, accuracy: 96.65
# Epoch 10:	########################################	elapsed: 0.59s, accuracy: 96.33
# Epoch 11:	########################################	elapsed: 0.75s, accuracy: 96.84
# Epoch 12:	########################################	elapsed: 0.58s, accuracy: 97.03
# Epoch 13:	########################################	elapsed: 0.63s, accuracy: 97.09
# Epoch 14:	########################################	elapsed: 0.61s, accuracy: 97.24
# Epoch 15:	########################################	elapsed: 0.73s, accuracy: 97.15
# Epoch 16:	########################################	elapsed: 0.88s, accuracy: 97.12
# Epoch 17:	########################################	elapsed: 0.81s, accuracy: 97.14
# Epoch 18:	########################################	elapsed: 0.65s, accuracy: 97.19
# Epoch 19:	########################################	elapsed: 0.66s, accuracy: 97.25
# Epoch 20:	########################################	elapsed: 0.92s, accuracy: 97.27
# Epoch 21:	########################################	elapsed: 0.83s, accuracy: 97.25
# Epoch 22:	########################################	elapsed: 0.61s, accuracy: 97.26
# Epoch 23:	########################################	elapsed: 0.67s, accuracy: 97.22
# Epoch 25:	########################################	elapsed: 0.80s, accuracy: 95.71
# Epoch 26:	########################################	elapsed: 0.79s, accuracy: 95.82
# Epoch 27:	########################################	elapsed: 0.80s, accuracy: 95.88
# Epoch 28:	########################################	elapsed: 0.87s, accuracy: 96.37
# Epoch 29:	########################################	elapsed: 0.82s, accuracy: 96.51
# Epoch 30:	########################################	elapsed: 1.03s, accuracy: 96.54
# Epoch 31:	########################################	elapsed: 0.84s, accuracy: 96.55
# Epoch 32:	########################################	elapsed: 0.84s, accuracy: 96.56
# Epoch 33:	########################################	elapsed: 0.83s, accuracy: 96.56
# Epoch 34:	########################################	elapsed: 0.80s, accuracy: 96.57
# Epoch 35:	########################################	elapsed: 1.25s, accuracy: 96.57
# Epoch 36:	########################################	elapsed: 0.97s, accuracy: 96.56
# Epoch 37:	########################################	elapsed: 0.85s, accuracy: 96.55
# Epoch 38:	########################################	elapsed: 0.97s, accuracy: 96.55
# Epoch 39:	########################################	elapsed: 0.80s, accuracy: 96.55
# Epoch 40:	########################################	elapsed: 0.83s, accuracy: 96.54
# Epoch 41:	########################################	elapsed: 0.83s, accuracy: 96.51
# Epoch 42:	########################################	elapsed: 0.82s, accuracy: 96.50
# Epoch 43:	########################################	elapsed: 0.85s, accuracy: 96.50
# Epoch 44:	########################################	elapsed: 0.83s, accuracy: 96.49
# Epoch 45:	########################################	elapsed: 0.93s, accuracy: 96.50
# Epoch 46:	########################################	elapsed: 0.82s, accuracy: 96.50
# Epoch 47:	########################################	elapsed: 0.84s, accuracy: 96.50
# Epoch 48:	########################################	elapsed: 0.87s, accuracy: 96.48
# Epoch 49:	########################################	elapsed: 0.86s, accuracy: 96.49
# Epoch 50:	########################################	elapsed: 0.81s, accuracy: 96.49
# Training finished!
# <h3>Input layer filters in the plain MLP</h3>
# <h3>Largest norms of weight-vectors in the plain MLP layers</h3>
# 	layer 1: 2.00
# 	layer 2: 1.00
# 	layer 3: 0.90
# 	layer 4: 4.00
# <h3>DBN training</h3>
# Learning layer 1
# Epoch 1:	########################################	elapsed: 0.85s, reconstruction error: 73.17
# Epoch 2:	########################################	elapsed: 0.67s, reconstruction error: 52.85
# Epoch 3:	########################################	elapsed: 0.66s, reconstruction error: 41.32
# Epoch 4:	########################################	elapsed: 0.65s, reconstruction error: 35.15
# Epoch 5:	########################################	elapsed: 0.64s, reconstruction error: 31.43
# Epoch 6:	########################################	elapsed: 0.64s, reconstruction error: 23.39
# Epoch 7:	########################################	elapsed: 0.66s, reconstruction error: 19.49
# Epoch 8:	########################################	elapsed: 0.65s, reconstruction error: 17.22
# Epoch 9:	########################################	elapsed: 0.65s, reconstruction error: 15.44
# Epoch 10:	########################################	elapsed: 0.65s, reconstruction error: 14.20
# Epoch 11:	########################################	elapsed: 0.67s, reconstruction error: 13.17
# Epoch 12:	########################################	elapsed: 0.70s, reconstruction error: 12.24
# Epoch 13:	########################################	elapsed: 0.69s, reconstruction error: 11.51
# Epoch 14:	########################################	elapsed: 0.69s, reconstruction error: 10.86
# Epoch 15:	########################################	elapsed: 0.72s, reconstruction error: 10.35
# Epoch 16:	########################################	elapsed: 0.70s, reconstruction error: 9.79
# Epoch 17:	########################################	elapsed: 0.73s, reconstruction error: 9.40
# Epoch 18:	########################################	elapsed: 0.74s, reconstruction error: 8.97
# Epoch 19:	########################################	elapsed: 0.74s, reconstruction error: 8.64
# Epoch 20:	########################################	elapsed: 0.74s, reconstruction error: 8.32
# Epoch 21:	########################################	elapsed: 0.73s, reconstruction error: 8.04
# Epoch 22:	########################################	elapsed: 0.75s, reconstruction error: 7.83
# Epoch 23:	########################################	elapsed: 0.75s, reconstruction error: 7.64
# Epoch 24:	########################################	elapsed: 0.74s, reconstruction error: 7.51
# Epoch 25:	########################################	elapsed: 0.75s, reconstruction error: 7.28
# Epoch 26:	########################################	elapsed: 0.75s, reconstruction error: 7.18
# Epoch 27:	########################################	elapsed: 0.73s, reconstruction error: 7.04
# Epoch 28:	########################################	elapsed: 0.73s, reconstruction error: 6.88
# Epoch 29:	########################################	elapsed: 0.76s, reconstruction error: 6.82
# Epoch 30:	########################################	elapsed: 0.75s, reconstruction error: 6.75
# Epoch 31:	########################################	elapsed: 0.73s, reconstruction error: 6.60
# Epoch 32:	########################################	elapsed: 0.75s, reconstruction error: 6.55
# Epoch 33:	########################################	elapsed: 0.76s, reconstruction error: 6.50
# Epoch 34:	########################################	elapsed: 0.77s, reconstruction error: 6.38
# Epoch 35:	########################################	elapsed: 0.72s, reconstruction error: 6.38
# Epoch 36:	########################################	elapsed: 0.75s, reconstruction error: 6.30
# Epoch 37:	########################################	elapsed: 0.76s, reconstruction error: 6.21
# Epoch 38:	########################################	elapsed: 0.75s, reconstruction error: 6.18
# Epoch 39:	########################################	elapsed: 0.75s, reconstruction error: 6.15
# Epoch 40:	########################################	elapsed: 0.79s, reconstruction error: 6.11
# Epoch 41:	########################################	elapsed: 0.74s, reconstruction error: 6.08
# Epoch 42:	########################################	elapsed: 0.77s, reconstruction error: 6.03
# Epoch 43:	########################################	elapsed: 0.75s, reconstruction error: 5.98
# Epoch 44:	########################################	elapsed: 0.77s, reconstruction error: 5.96
# Epoch 45:	########################################	elapsed: 0.73s, reconstruction error: 5.93
# Epoch 46:	########################################	elapsed: 0.75s, reconstruction error: 5.90
# Epoch 47:	########################################	elapsed: 0.74s, reconstruction error: 5.84
# Epoch 48:	########################################	elapsed: 0.77s, reconstruction error: 5.86
# Epoch 49:	########################################	elapsed: 0.75s, reconstruction error: 5.85
# Epoch 50:	########################################	elapsed: 0.75s, reconstruction error: 5.76
#
# Learning layer 2
# Epoch 1:	########################################	elapsed: 0.50s, reconstruction error: 57.16
# Epoch 2:	########################################	elapsed: 0.52s, reconstruction error: 56.64
# Epoch 3:	########################################	elapsed: 0.60s, reconstruction error: 54.68
# Epoch 4:	########################################	elapsed: 0.60s, reconstruction error: 52.56
# Epoch 5:	########################################	elapsed: 0.58s, reconstruction error: 51.45
# Epoch 6:	########################################	elapsed: 0.60s, reconstruction error: 48.87
# Epoch 7:	########################################	elapsed: 0.66s, reconstruction error: 48.15
# Epoch 8:	########################################	elapsed: 0.64s, reconstruction error: 47.31
# Epoch 9:	########################################	elapsed: 0.62s, reconstruction error: 46.96
# Epoch 10:	########################################	elapsed: 0.58s, reconstruction error: 46.40
# Epoch 11:	########################################	elapsed: 0.62s, reconstruction error: 45.60
# Epoch 12:	########################################	elapsed: 0.66s, reconstruction error: 45.83
# Epoch 13:	########################################	elapsed: 0.62s, reconstruction error: 45.34
# Epoch 14:	########################################	elapsed: 0.56s, reconstruction error: 45.00
# Epoch 15:	########################################	elapsed: 0.65s, reconstruction error: 45.04
# Epoch 16:	########################################	elapsed: 0.59s, reconstruction error: 44.59
# Epoch 17:	########################################	elapsed: 0.59s, reconstruction error: 44.59
# Epoch 18:	########################################	elapsed: 0.51s, reconstruction error: 44.79
# Epoch 19:	########################################	elapsed: 0.49s, reconstruction error: 45.09
# Epoch 20:	########################################	elapsed: 0.56s, reconstruction error: 44.83
# Epoch 21:	########################################	elapsed: 0.63s, reconstruction error: 44.86
# Epoch 22:	########################################	elapsed: 0.60s, reconstruction error: 44.74
# Epoch 23:	########################################	elapsed: 0.58s, reconstruction error: 45.07
# Epoch 24:	########################################	elapsed: 0.66s, reconstruction error: 45.25
# Epoch 25:	########################################	elapsed: 0.65s, reconstruction error: 45.05
# Epoch 26:	########################################	elapsed: 0.60s, reconstruction error: 44.74
# Epoch 27:	########################################	elapsed: 0.61s, reconstruction error: 44.89
# Epoch 28:	########################################	elapsed: 0.50s, reconstruction error: 45.00
# Epoch 29:	########################################	elapsed: 0.49s, reconstruction error: 44.56
# Epoch 30:	########################################	elapsed: 0.50s, reconstruction error: 44.48
# Epoch 31:	########################################	elapsed: 0.63s, reconstruction error: 44.86
# Epoch 32:	########################################	elapsed: 0.63s, reconstruction error: 45.02
# Epoch 33:	########################################	elapsed: 0.61s, reconstruction error: 44.79
# Epoch 34:	########################################	elapsed: 0.68s, reconstruction error: 44.84
# Epoch 35:	########################################	elapsed: 0.52s, reconstruction error: 44.83
# Epoch 36:	########################################	elapsed: 0.60s, reconstruction error: 44.91
# Epoch 37:	########################################	elapsed: 0.53s, reconstruction error: 44.71
# Epoch 38:	########################################	elapsed: 0.59s, reconstruction error: 44.72
# Epoch 39:	########################################	elapsed: 0.59s, reconstruction error: 44.62
# Epoch 40:	########################################	elapsed: 0.67s, reconstruction error: 44.42
# Epoch 41:	########################################	elapsed: 0.65s, reconstruction error: 44.37
# Epoch 42:	########################################	elapsed: 0.66s, reconstruction error: 44.51
# Epoch 43:	########################################	elapsed: 0.62s, reconstruction error: 44.97
# Epoch 44:	########################################	elapsed: 0.66s, reconstruction error: 44.74
# Epoch 45:	########################################	elapsed: 0.65s, reconstruction error: 44.63
# Epoch 46:	########################################	elapsed: 0.63s, reconstruction error: 44.47
# Epoch 47:	########################################	elapsed: 0.62s, reconstruction error: 44.61
# Epoch 48:	########################################	elapsed: 0.62s, reconstruction error: 44.47
# Epoch 49:	########################################	elapsed: 0.65s, reconstruction error: 44.61
# Epoch 50:	########################################	elapsed: 0.66s, reconstruction error: 44.80
#
# Learning layer 3
# Epoch 1:	########################################	elapsed: 0.63s, reconstruction error: 50.25
# Epoch 2:	########################################	elapsed: 0.68s, reconstruction error: 51.27
# Epoch 3:	########################################	elapsed: 0.82s, reconstruction error: 51.13
# Epoch 4:	########################################	elapsed: 0.82s, reconstruction error: 51.06
# Epoch 5:	########################################	elapsed: 0.82s, reconstruction error: 51.02
# Epoch 6:	########################################	elapsed: 0.81s, reconstruction error: 50.77
# Epoch 7:	########################################	elapsed: 0.78s, reconstruction error: 50.77
# Epoch 8:	########################################	elapsed: 0.75s, reconstruction error: 50.76
# Epoch 9:	########################################	elapsed: 0.81s, reconstruction error: 50.75
# Epoch 10:	########################################	elapsed: 0.74s, reconstruction error: 50.74
# Epoch 11:	########################################	elapsed: 0.81s, reconstruction error: 50.75
# Epoch 12:	########################################	elapsed: 0.79s, reconstruction error: 50.76
# Epoch 13:	########################################	elapsed: 0.81s, reconstruction error: 50.74
# Epoch 14:	########################################	elapsed: 0.72s, reconstruction error: 50.74
# Epoch 15:	########################################	elapsed: 0.76s, reconstruction error: 50.77
# Epoch 16:	########################################	elapsed: 0.72s, reconstruction error: 50.76
# Epoch 17:	########################################	elapsed: 0.81s, reconstruction error: 50.78
# Epoch 18:	########################################	elapsed: 0.77s, reconstruction error: 50.73
# Epoch 19:	########################################	elapsed: 0.72s, reconstruction error: 50.74
# Epoch 20:	########################################	elapsed: 0.71s, reconstruction error: 50.75
# Epoch 21:	########################################	elapsed: 0.78s, reconstruction error: 50.73
# Epoch 22:	########################################	elapsed: 0.74s, reconstruction error: 50.79
# Epoch 23:	########################################	elapsed: 0.80s, reconstruction error: 50.74
# Epoch 24:	########################################	elapsed: 0.74s, reconstruction error: 50.78
# Epoch 25:	########################################	elapsed: 0.70s, reconstruction error: 50.78
# Epoch 26:	########################################	elapsed: 0.79s, reconstruction error: 50.78
# Epoch 27:	########################################	elapsed: 0.68s, reconstruction error: 50.79
# Epoch 28:	########################################	elapsed: 0.62s, reconstruction error: 50.73
# Epoch 29:	########################################	elapsed: 0.79s, reconstruction error: 50.78
# Epoch 30:	########################################	elapsed: 0.69s, reconstruction error: 50.74
# Epoch 31:	########################################	elapsed: 0.70s, reconstruction error: 50.74
# Epoch 32:	########################################	elapsed: 0.63s, reconstruction error: 50.72
# Epoch 33:	########################################	elapsed: 0.59s, reconstruction error: 50.75
# Epoch 34:	########################################	elapsed: 0.72s, reconstruction error: 50.72
# Epoch 35:	########################################	elapsed: 0.82s, reconstruction error: 50.72
# Epoch 36:	########################################	elapsed: 0.80s, reconstruction error: 50.74
# Epoch 37:	########################################	elapsed: 0.80s, reconstruction error: 50.74
# Epoch 38:	########################################	elapsed: 0.73s, reconstruction error: 50.74
# Epoch 39:	########################################	elapsed: 0.76s, reconstruction error: 50.79
# Epoch 40:	########################################	elapsed: 0.74s, reconstruction error: 50.72
# Epoch 41:	########################################	elapsed: 0.64s, reconstruction error: 50.75
# Epoch 42:	########################################	elapsed: 0.71s, reconstruction error: 50.73
# Epoch 43:	########################################	elapsed: 0.78s, reconstruction error: 50.73
# Epoch 44:	########################################	elapsed: 0.78s, reconstruction error: 50.80
# Epoch 45:	########################################	elapsed: 0.82s, reconstruction error: 50.78
# Epoch 46:	########################################	elapsed: 0.75s, reconstruction error: 50.76
# Epoch 47:	########################################	elapsed: 0.76s, reconstruction error: 50.75
# Epoch 48:	########################################	elapsed: 0.70s, reconstruction error: 50.75
# Epoch 49:	########################################	elapsed: 0.65s, reconstruction error: 50.76
# Epoch 50:	########################################	elapsed: 0.73s, reconstruction error: 50.75
# <h3>Finetuning pretrained MLP</h3>
# Epoch 1:	########################################	elapsed: