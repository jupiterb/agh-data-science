# %%
import numpy as np
import matplotlib.pyplot as plt
import time
% import mkl

# %mkl.set_num_threads(2)
np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]
# Out:
# UsageError: Line magic function `%` not found.

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix, axis=1):
    return np.concatenate((matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis)

def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def chunks(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def as_matrix(vector):
    return np.reshape(vector, (-1, 1))

def one_hot_encode(labels):
    one_hot = zeros(labels.shape[0], np.max(labels) + 1) 
    one_hot[np.arange(labels.shape[0]), labels] = 1
    return one_hot.astype(np.float32)

def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]
    
    space_between_tiles = 2
    img_matrix = np.empty(shape=(rows_count * (tile_height + space_between_tiles) - space_between_tiles,  
                                 cols_count * (tile_width + space_between_tiles) - space_between_tiles))
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0:x_0 + tile_height, y_0:y_0 + tile_width] = (examples[r, c] - ex_min) / (ex_max - ex_min)
    
    plt.matshow(img_matrix, cmap='gray', interpolation='none')
    plt.axis('off')
    plt.show()

# %% [markdown]
# ### Activation functions

# %%
def sigmoid(batch):
    return 1.0 / (1.0 + np.exp(-batch))

def sigmoid_derivative(batch):
    s = sigmoid(batch)
    return s * (1.0 - s)

# %% [markdown]
# # MNIST dataset

# %%
import mnist
digits = np.reshape(mnist.train_images()[:12*24], newshape=(12, 24, 28, 28))
tiles(digits)

# %% [markdown]
# # Part 1: $L^1$ and $L^2$ penalties

# %%
class Rbm:
    def __init__(self, visible_size, hidden_size, learning_rate, momentum, l1_penalty, l2_penalty):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.l1_penalty = l1_penalty
        self.l2_penalty = l2_penalty
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size+1)).astype(np.float32)
        self.W[:, -1] = 0.0
        self.W[-1, :] = 0.0
        self.M = zeros(self.visible_size+1, self.hidden_size+1)

# %%
# equations utils

get_hidden = lambda visible, W: sigmoid(visible @ W[:, :-1])
get_visible = lambda hidden, W: sigmoid(hidden @ W[:-1, :].T)
get_grad = lambda hidden, visible: (visible.T @ hidden)
activation_proba = lambda neurons: neurons > rand(*neurons.shape)

# %%
def reconstuction_error(rbm, minibatch):
    observations_count = minibatch.shape[0]
    
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    hidden[:, :-1] = activation_proba(get_hidden(minibatch, rbm.W))
    
    visible = get_visible(hidden, rbm.W)
    
    error = np.sum((minibatch[:, :-1] - visible) ** 2) / observations_count

    return error

# %%
def train_epoch(rbm, dataset, batch_size):
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(rbm, batch)
        if batch_idx % round(batches_limit / 40) == 0: print("#", end="")

def run_training(rbm, dataset, monitoring_set, batch_size, epochs_count):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch+1),  end="\t")
        
        if epoch == 5:
            rbm.momentum = 0.8

        start_time = time.time()
        train_epoch(rbm, dataset, batch_size)
        elapsed = time.time() - start_time
        
        error = reconstuction_error(rbm, monitoring_set)
        print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))

    print("Training finished!")

def draw_filters(rbm):
    filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
    tiles(filters)

# %% [markdown]
# ### CDK with regulatization
#
# Implement the Contrastive Divergence algorithm with $L^1$ and $L^2$ penalties. If
# ```python
# rbm.l1_penalty > 0
# ```
# the algorithm should constrain the weights with $L^1$ penalty. Otherwise, if
# ```python
# rbm.l2_penalty > 0
# ```
# the algorithm should constrain the weights with $L^2$ penalty.
#
# Do **not** apply the penalties to the biases!

# %%
def cdk(rbm, minibatch, k=1):
    observations_count = minibatch.shape[0]

    positive_visible = minibatch
    negative_visible = append_ones(zeros(observations_count, rbm.visible_size))

    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_hidden = append_ones(zeros(observations_count, rbm.hidden_size))

    # positive phase
    positive_hidden[:, :-1] = get_hidden(positive_visible, rbm.W)
    grad_p = get_grad(positive_hidden, positive_visible) / observations_count

    # negative phase
    negative_hidden[:, :-1] = activation_proba(positive_hidden[:, :-1])
    negative_visible[:, :-1] = activation_proba(get_visible(negative_hidden, rbm.W))

    for _ in range(k - 1):
        negative_hidden[:, :-1] = activation_proba(get_hidden(negative_visible, rbm.W))
        negative_visible[:, :-1] = activation_proba(get_visible(negative_hidden, rbm.W))

    negative_hidden[:, :-1] = get_hidden(negative_visible, rbm.W)
    grad_n = get_grad(negative_hidden, negative_visible) / observations_count
    
    grad = rbm.learning_rate * (grad_p - grad_n)

    # regularization
    grad[:-1, :-1] += rbm.l1_penalty * np.sign(rbm.W[:-1, :-1]) / observations_count
    grad[:-1, :-1] += rbm.l2_penalty * rbm.W[:-1, :-1] / observations_count

    # update weight with momentum
    rbm.M = rbm.momentum * rbm.M + grad
    rbm.W += rbm.M

# %% [markdown]
# ## Comparison of regularization penalties

# %%
DATASET_SIZE = 20000 # 60000 for whole dataset
DIGIT_SIZE = 28

VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE
HIDDEN_LAYER_SIZE = 128

mnist_train = mnist.train_images().astype(np.float32) / 255.0
np.random.shuffle(mnist_train)
dataset = np.reshape(mnist_train[:DATASET_SIZE], newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
dataset = append_ones(dataset)

monitoring_indeces = np.random.choice(DATASET_SIZE, 256, replace=False)
monitoring_set = dataset[monitoring_indeces]

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 50

LEARNING_RATE = 0.1
MOMENTUM = 0.5

# %% [markdown]
# ### RBM with no regularization

# %%
L1_PENALTY = 0.0
L2_PENALTY = 0.0

np.random.seed(1234)
rbm_plain = Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM, L1_PENALTY, L2_PENALTY)

run_training(rbm_plain, dataset, monitoring_set, BATCH_SIZE, EPOCHS_COUNT)
# Out:
# Epoch 1:	########################################	elapsed: 0.99s, reconstruction error: 26.52
# Epoch 2:	########################################	elapsed: 0.99s, reconstruction error: 21.22
# Epoch 3:	########################################	elapsed: 0.90s, reconstruction error: 18.76
# Epoch 4:	########################################	elapsed: 0.94s, reconstruction error: 17.26
# Epoch 5:	########################################	elapsed: 0.92s, reconstruction error: 16.38
# Epoch 6:	########################################	elapsed: 0.95s, reconstruction error: 15.20
# Epoch 7:	########################################	elapsed: 0.94s, reconstruction error: 14.27
# Epoch 8:	########################################	elapsed: 0.94s, reconstruction error: 13.63
# Epoch 9:	########################################	elapsed: 0.94s, reconstruction error: 12.99
# Epoch 10:	########################################	elapsed: 0.91s, reconstruction error: 12.83
# Epoch 11:	########################################	elapsed: 0.90s, reconstruction error: 12.52
# Epoch 12:	########################################	elapsed: 0.96s, reconstruction error: 12.09
# Epoch 13:	########################################	elapsed: 0.92s, reconstruction error: 12.11
# Epoch 14:	########################################	elapsed: 1.35s, reconstruction error: 11.72
# Epoch 15:	########################################	elapsed: 1.51s, reconstruction error: 11.67
# Epoch 16:	########################################	elapsed: 1.51s, reconstruction error: 11.55
# Epoch 17:	########################################	elapsed: 1.54s, reconstruction error: 11.38
# Epoch 18:	########################################	elapsed: 1.48s, reconstruction error: 11.14
# Epoch 19:	########################################	elapsed: 1.49s, reconstruction error: 11.13
# Epoch 20:	########################################	elapsed: 1.52s, reconstruction error: 11.20
# Epoch 21:	########################################	elapsed: 1.55s, reconstruction error: 10.95
# Epoch 22:	########################################	elapsed: 1.52s, reconstruction error: 10.87
# Epoch 23:	########################################	elapsed: 1.52s, reconstruction error: 10.94
# Epoch 24:	########################################	elapsed: 1.49s, reconstruction error: 10.82
# Epoch 25:	########################################	elapsed: 1.48s, reconstruction error: 10.85
# Epoch 26:	########################################	elapsed: 1.51s, reconstruction error: 10.74
# Epoch 27:	########################################	elapsed: 1.54s, reconstruction error: 10.65
# Epoch 28:	########################################	elapsed: 1.52s, reconstruction error: 10.77
# Epoch 29:	########################################	elapsed: 1.51s, reconstruction error: 10.63
# Epoch 30:	########################################	elapsed: 1.55s, reconstruction error: 10.66
# Epoch 31:	########################################	elapsed: 1.55s, reconstruction error: 10.73
# Epoch 32:	########################################	elapsed: 1.55s, reconstruction error: 10.50
# Epoch 33:	########################################	elapsed: 1.58s, reconstruction error: 10.46
# Epoch 34:	########################################	elapsed: 1.56s, reconstruction error: 10.59
# Epoch 35:	########################################	elapsed: 1.54s, reconstruction error: 10.43
# Epoch 36:	########################################	elapsed: 1.60s, reconstruction error: 10.41
# Epoch 37:	########################################	elapsed: 1.54s, reconstruction error: 10.48
# Epoch 38:	########################################	elapsed: 1.51s, reconstruction error: 10.39
# Epoch 39:	########################################	elapsed: 1.51s, reconstruction error: 10.48
# Epoch 40:	########################################	elapsed: 1.52s, reconstruction error: 10.56
# Epoch 41:	###################
# C:\Users\pbial\AppData\Local\Temp\ipykernel_1336\3565745247.py:2: RuntimeWarning: overflow encountered in exp
#   return 1.0 / (1.0 + np.exp(-batch))
# #####################	elapsed: 1.53s, reconstruction error: 10.57
# Epoch 42:	########################################	elapsed: 1.50s, reconstruction error: 10.41
# Epoch 43:	########################################	elapsed: 1.56s, reconstruction error: 10.33
# Epoch 44:	########################################	elapsed: 1.68s, reconstruction error: 10.33
# Epoch 45:	########################################	elapsed: 1.67s, reconstruction error: 10.23
# Epoch 46:	########################################	elapsed: 1.76s, reconstruction error: 10.32
# Epoch 47:	########################################	elapsed: 1.75s, reconstruction error: 10.20
# Epoch 48:	########################################	elapsed: 1.66s, reconstruction error: 10.26
# Epoch 49:	########################################	elapsed: 1.61s, reconstruction error: 10.12
# Epoch 50:	########################################	elapsed: 1.65s, reconstruction error: 10.32
# Training finished!

# %% [markdown]
# ### RBM with $L^1$ penalty

# %%
L1_PENALTY = 0.0001
L2_PENALTY = 0.0

np.random.seed(1234)
rbm_l1 = Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM, L1_PENALTY, L2_PENALTY)

run_training(rbm_l1, dataset, monitoring_set, BATCH_SIZE, EPOCHS_COUNT)
# Out:
# Epoch 1:	########################################	elapsed: 1.62s, reconstruction error: 26.53
# Epoch 2:	########################################	elapsed: 1.63s, reconstruction error: 21.22
# Epoch 3:	########################################	elapsed: 1.52s, reconstruction error: 18.79
# Epoch 4:	########################################	elapsed: 1.55s, reconstruction error: 17.25
# Epoch 5:	########################################	elapsed: 1.52s, reconstruction error: 16.43
# Epoch 6:	########################################	elapsed: 1.57s, reconstruction error: 15.15
# Epoch 7:	########################################	elapsed: 1.75s, reconstruction error: 14.26
# Epoch 8:	########################################	elapsed: 1.82s, reconstruction error: 13.70
# Epoch 9:	########################################	elapsed: 1.62s, reconstruction error: 13.00
# Epoch 10:	########################################	elapsed: 1.49s, reconstruction error: 12.79
# Epoch 11:	########################################	elapsed: 1.65s, reconstruction error: 12.50
# Epoch 12:	########################################	elapsed: 1.52s, reconstruction error: 12.26
# Epoch 13:	########################################	elapsed: 1.63s, reconstruction error: 12.25
# Epoch 14:	########################################	elapsed: 1.56s, reconstruction error: 11.72
# Epoch 15:	########################################	elapsed: 1.55s, reconstruction error: 11.77
# Epoch 16:	########################################	elapsed: 1.48s, reconstruction error: 11.61
# Epoch 17:	########################################	elapsed: 1.54s, reconstruction error: 11.43
# Epoch 18:	########################################	elapsed: 1.55s, reconstruction error: 11.15
# Epoch 19:	########################################	elapsed: 1.52s, reconstruction error: 11.24
# Epoch 20:	########################################	elapsed: 1.62s, reconstruction error: 11.30
# Epoch 21:	########################################	elapsed: 1.62s, reconstruction error: 11.02
# Epoch 22:	########################################	elapsed: 1.56s, reconstruction error: 11.06
# Epoch 23:	########################################	elapsed: 1.58s, reconstruction error: 10.98
# Epoch 24:	########################################	elapsed: 1.53s, reconstruction error: 10.74
# Epoch 25:	########################################	elapsed: 1.68s, reconstruction error: 10.85
# Epoch 26:	########################################	elapsed: 1.56s, reconstruction error: 10.85
# Epoch 27:	########################################	elapsed: 1.51s, reconstruction error: 10.78
# Epoch 28:	########################################	elapsed: 1.57s, reconstruction error: 10.88
# Epoch 29:	########################################	elapsed: 1.54s, reconstruction error: 10.71
# Epoch 30:	########################################	elapsed: 1.57s, reconstruction error: 10.65
# Epoch 31:	########################################	elapsed: 1.52s, reconstruction error: 10.73
# Epoch 32:	########################################	elapsed: 1.57s, reconstruction error: 10.56
# Epoch 33:	########################################	elapsed: 1.49s, reconstruction error: 10.60
# Epoch 34:	########################################	elapsed: 1.59s, reconstruction error: 10.72
# Epoch 35:	########################################	elapsed: 1.60s, reconstruction error: 10.34
# Epoch 36:	########################################	elapsed: 1.50s, reconstruction error: 10.63
# Epoch 37:	########################################	elapsed: 1.58s, reconstruction error: 10.39
# Epoch 38:	########################################	elapsed: 1.60s, reconstruction error: 10.45
# Epoch 39:	########################################	elapsed: 1.58s, reconstruction error: 10.30
# Epoch 40:	########################################	elapsed: 1.61s, reconstruction error: 10.44
# Epoch 41:	########################################	elapsed: 1.65s, reconstruction error: 10.39
# Epoch 42:	########################################	elapsed: 1.65s, reconstruction error: 10.35
# Epoch 43:	############
# C:\Users\pbial\AppData\Local\Temp\ipykernel_1336\3565745247.py:2: RuntimeWarning: overflow encountered in exp
#   return 1.0 / (1.0 + np.exp(-batch))
# ############################	elapsed: 1.56s, reconstruction error: 10.35
# Epoch 44:	########################################	elapsed: 1.66s, reconstruction error: 10.24
# Epoch 45:	########################################	elapsed: 1.59s, reconstruction error: 10.32
# Epoch 46:	########################################	elapsed: 1.66s, reconstruction error: 10.26
# Epoch 47:	########################################	elapsed: 1.51s, reconstruction error: 10.20
# Epoch 48:	########################################	elapsed: 1.63s, reconstruction error: 10.27
# Epoch 49:	########################################	elapsed: 1.58s, reconstruction error: 10.20
# Epoch 50:	########################################	elapsed: 1.71s, reconstruction error: 10.21
# Training finished!

# %% [markdown]
# ### RBM with $L^2$ penalty

# %%
L1_PENALTY = 0.0
L2_PENALTY = 0.0005

np.random.seed(1234)
rbm_l2 = Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM, L1_PENALTY, L2_PENALTY)

run_training(rbm_l2, dataset, monitoring_set, BATCH_SIZE, EPOCHS_COUNT)
# Out:
# Epoch 1:	########################################	elapsed: 1.64s, reconstruction error: 26.52
# Epoch 2:	########################################	elapsed: 1.65s, reconstruction error: 21.24
# Epoch 3:	########################################	elapsed: 1.65s, reconstruction error: 18.79
# Epoch 4:	########################################	elapsed: 1.56s, reconstruction error: 17.28
# Epoch 5:	########################################	elapsed: 1.57s, reconstruction error: 16.47
# Epoch 6:	########################################	elapsed: 1.60s, reconstruction error: 15.16
# Epoch 7:	########################################	elapsed: 1.56s, reconstruction error: 14.27
# Epoch 8:	########################################	elapsed: 1.60s, reconstruction error: 13.67
# Epoch 9:	########################################	elapsed: 1.61s, reconstruction error: 13.03
# Epoch 10:	########################################	elapsed: 1.59s, reconstruction error: 12.82
# Epoch 11:	########################################	elapsed: 1.75s, reconstruction error: 12.44
# Epoch 12:	########################################	elapsed: 1.70s, reconstruction error: 12.14
# Epoch 13:	########################################	elapsed: 1.70s, reconstruction error: 12.12
# Epoch 14:	########################################	elapsed: 1.65s, reconstruction error: 11.67
# Epoch 15:	########################################	elapsed: 1.65s, reconstruction error: 11.59
# Epoch 16:	########################################	elapsed: 1.63s, reconstruction error: 11.56
# Epoch 17:	########################################	elapsed: 1.59s, reconstruction error: 11.48
# Epoch 18:	########################################	elapsed: 1.56s, reconstruction error: 11.12
# Epoch 19:	########################################	elapsed: 1.63s, reconstruction error: 11.21
# Epoch 20:	########################################	elapsed: 1.66s, reconstruction error: 11.25
# Epoch 21:	########################################	elapsed: 1.64s, reconstruction error: 10.99
# Epoch 22:	########################################	elapsed: 1.67s, reconstruction error: 11.06
# Epoch 23:	########################################	elapsed: 1.58s, reconstruction error: 10.99
# Epoch 24:	########################################	elapsed: 1.60s, reconstruction error: 10.85
# Epoch 25:	########################################	elapsed: 1.65s, reconstruction error: 10.94
# Epoch 26:	########################################	elapsed: 1.67s, reconstruction error: 10.81
# Epoch 27:	########################################	elapsed: 1.65s, reconstruction error: 10.89
# Epoch 28:	########################################	elapsed: 1.60s, reconstruction error: 10.79
# Epoch 29:	########################################	elapsed: 1.56s, reconstruction error: 10.65
# Epoch 30:	########################################	elapsed: 1.68s, reconstruction error: 10.67
# Epoch 31:	########################################	elapsed: 1.72s, reconstruction error: 10.75
# Epoch 32:	########################################	elapsed: 1.76s, reconstruction error: 10.69
# Epoch 33:	########################################	elapsed: 1.66s, reconstruction error: 10.58
# Epoch 34:	########################################	elapsed: 1.66s, reconstruction error: 10.57
# Epoch 35:	########################################	elapsed: 1.62s, reconstruction error: 10.39
# Epoch 36:	########################################	elapsed: 1.61s, reconstruction error: 10.54
# Epoch 37:	########################################	elapsed: 1.64s, reconstruction error: 10.47
# Epoch 38:	#########
# C:\Users\pbial\AppData\Local\Temp\ipykernel_1336\3565745247.py:2: RuntimeWarning: overflow encountered in exp
#   return 1.0 / (1.0 + np.exp(-batch))
# ###############################	elapsed: 1.66s, reconstruction error: 10.42
# Epoch 39:	########################################	elapsed: 1.74s, reconstruction error: 10.32
# Epoch 40:	########################################	elapsed: 1.65s, reconstruction error: 10.44
# Epoch 41:	########################################	elapsed: 1.62s, reconstruction error: 10.45
# Epoch 42:	########################################	elapsed: 1.63s, reconstruction error: 10.37
# Epoch 43:	########################################	elapsed: 1.64s, reconstruction error: 10.28
# Epoch 44:	########################################	elapsed: 1.65s, reconstruction error: 10.34
# Epoch 45:	########################################	elapsed: 1.64s, reconstruction error: 10.19
# Epoch 46:	########################################	elapsed: 1.59s, reconstruction error: 10.34
# Epoch 47:	########################################	elapsed: 1.68s, reconstruction error: 10.15
# Epoch 48:	########################################	elapsed: 1.76s, reconstruction error: 10.27
# Epoch 49:	########################################	elapsed: 1.73s, reconstruction error: 10.10
# Epoch 50:	########################################	elapsed: 1.68s, reconstruction error: 10.25
# Training finished!

# %% [markdown]
# ### Plain filters

# %%
draw_filters(rbm_plain)

# %% [markdown]
# ### $L^1$ filters

# %%
draw_filters(rbm_l1)

# %% [markdown]
# ### $L^2$ filters

# %%
draw_filters(rbm_l2)

# %% [markdown]
# # Part 2: MLP pretraining

# %%
def softmax(batch):
    negative_batch = batch - np.max(batch, axis=-1, keepdims=True)
    numerator = np.exp(negative_batch)
    denominator = np.sum(numerator, axis=-1, keepdims=True)
    return numerator / denominator

# %%
class Layer:
    def __init__(self, visible_size, hidden_size, activation_fun, d_activation_fun, 
                 learning_rate, momentum, l2_penalty):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        
        self.activation_fun = activation_fun
        self.d_activation_fun = d_activation_fun
                
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.l2_penalty = l2_penalty
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size)).astype(np.float32)
        self.W[-1, :] = 0.0
        
        self.activations = None
        self.d_activations = None
        self.deltas = None

        self.M = zeros(self.visible_size+1, self.hidden_size)

# %% [markdown]
# ### Forward pass

# %%
def forward_pass(mlp, batch, compute_derivatives):
    visible = batch
    
    for layer_idx, layer in enumerate(mlp):
        z = visible @ layer.W
        layer.activations = append_ones(layer.activation_fun(z))
        
        if compute_derivatives and (layer_idx < len(mlp) - 1):
            layer.d_activations = layer.d_activation_fun(z)
        
        visible = layer.activations
        
    return visible[:, :-1]

# %% [markdown]
# ### Error backpropagation
#
# Extend the implementation of error backpropagation (from Lab 6) with $L^2$ penalty. Apply the penalty when:
# ```python
# rbm.l2_penalty > 0
# ```
#
# Do **not** apply the penalty to the biases.

# %%
def error_backpropagate(mlp, batch):
    observations_count = batch.shape[0]
    
    for layer_idx, layer in reversed(list(enumerate(mlp))):
        if layer_idx > 0:
            prev_layer = mlp[layer_idx - 1]
            visible = prev_layer.activations
            
            prev_layer.deltas = (layer.deltas @ layer.W[:-1].T) * prev_layer.d_activations
        else:
            visible = batch
        
        gradient = layer.learning_rate * (visible.T @ layer.deltas) / observations_count
        gradient[:-1] += layer.l2_penalty * layer.W[:-1] / observations_count
        
        layer.M = layer.momentum * layer.M - gradient
        
        layer.W += layer.M

# %% [markdown]
# ### MLP training

# %%
def train_mlp(mlp, dataset, labels, batch_size):
    batches_limit = dataset.shape[0] / batch_size
    
    batched_data = chunks(dataset, batch_size)
    batched_labels = chunks(labels, batch_size)
    
    for batch_idx, (batch, batch_labels) in enumerate(zip(batched_data, batched_labels)):
        # Forward pass: compute activatations and derivatives of activations
        y = forward_pass(mlp, batch, True)
        
        mlp[-1].deltas = y - batch_labels
        
        # Once softmax deltas are set, we may backpropagate errors
        error_backpropagate(mlp, batch)
        
        if batch_idx % round(batches_limit / 40) == 0: print("#", end="")

# %%
def classify(mlp, batch):
    probabilities = forward_pass(mlp, batch, False)
    return np.argmax(probabilities, axis=1)

def run_mlp_training(mlp, train_set, train_labels,
                     validation_set, validation_labels,
                     batch_size, epochs_count):
    
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch+1),  end="\t")
        
        if epoch == 5:
            for layer in mlp: layer.momentum = 0.9
        
        start_time = time.time()
        train_mlp(mlp, train_set, train_labels, batch_size)
        elapsed = time.time() - start_time

        predictions = classify(mlp, validation_set)
        accuracy = 100.0 * np.sum(predictions == validation_labels) / predictions.shape[0]
        print("\telapsed: {0:>2.2f}s, accuracy: {1:>2.2f}".format(elapsed, accuracy))

    print("Training finished!")
    
def draw_layer_filters(layer):
    filters = np.reshape(layer.W[:-1].T, newshape=(8, -1, 28, 28))
    tiles(filters)

# %% [markdown]
# ## DBN Pretraining

# %%
def propagate_up(dbn, layers_count, visible):
    for i in range(layers_count):
        visible = append_ones(sigmoid(visible @ dbn[i].W[:, :-1]))
    return visible

def propagate_down(dbn, layers_count, hidden):
    for i in reversed(range(layers_count)):
        hidden = append_ones(sigmoid(hidden @ np.transpose(dbn[i].W[:-1, :])))
    return hidden

# %%
def dbn_reconstuction_error(dbn, layers_count, minibatch):
    propagated = propagate_up(dbn, layers_count, minibatch)
    return reconstuction_error(dbn[layers_count], propagated)

# %%
def train_dbn_layer(dbn, layer_idx, dataset, batch_size):
    dataset = propagate_up(dbn, layer_idx, dataset)
    
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(dbn[layer_idx], batch)
        if batch_idx % round(batches_limit / 40) == 0: print("#", end="")

# %%
def train_dbn(dbn, dataset, monitoring_set, batch_size, epochs_count):
    for layer_idx in range(len(dbn)):
        print("\nLearning layer {}".format(layer_idx))
        
        for epoch in range(epochs_count):
            print("Epoch {}:".format(epoch+1),  end="\t")

            if epoch == 5:
                dbn[layer_idx].momentum = 0.9

            start_time = time.time()
            train_dbn_layer(dbn, layer_idx, dataset, batch_size)
            elapsed = time.time() - start_time

            error = dbn_reconstuction_error(dbn, layer_idx, monitoring_set)
            print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))

# %% [markdown]
# ##  Initializing MLP with DBN weights
#
# Implement initialization of MLP weights (and biases) using weights (and biases) from the DBN layers.
#
# Make sure that the MLP weights (and biases) are **copies** of the DBN weights (and biases). You can use ```np.copy(...)``` function to copy the weights (simple assignment will make a view instead of a copy).

# %%
def initialize_mlp(mlp, dbn):
    for layer_idx in range(len(dbn)):
        mlp[layer_idx].W = np.copy(dbn[layer_idx].W[:, :-1])

# %% [markdown]
# # MNIST digits classification

# %%
np.random.seed(1234)

DATASET_SIZE = 10000 # 60000 for whole dataset
DIGIT_SIZE = 28

##### Train set #####

mnist_train_images = mnist.train_images().astype(np.float32) / 255.0
mnist_train_labels = mnist.train_labels()

order = np.random.permutation(len(mnist_train_images))
mnist_train_images = mnist_train_images[order]
mnist_train_labels = mnist_train_labels[order]

mnist_train_images = np.reshape(mnist_train_images[:DATASET_SIZE],
                                newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
mnist_train_images = append_ones(mnist_train_images)

mnist_train_labels = mnist_train_labels[:DATASET_SIZE]
mnist_train_labels = one_hot_encode(mnist_train_labels)

monitoring_set_indeces = np.random.choice(mnist_train_images.shape[0], 512, replace=False)
monitoring_set = mnist_train_images[monitoring_set_indeces]

##### Test set #####

mnist_test_images = mnist.test_images().astype(np.float32) / 255.0
mnist_test_images = np.reshape(mnist_test_images, newshape=(-1, DIGIT_SIZE*DIGIT_SIZE))
mnist_test_images = append_ones(mnist_test_images)

mnist_test_labels = mnist.test_labels()

# %% [markdown]
# ### Plain vs pretrained MLP comparison

# %%
from IPython.core.display import HTML

def compare_pretraining_results(mlp, dbn,
                                train_set, train_labels,
                                validation_set, validation_labels,
                                monitoring_set,
                                batch_size, epochs_count):
    for layer in mlp:
        layer.reset()

    display(HTML('<h3>Plain MLP training</h3>'))
    run_mlp_training(mlp,
                     train_set, train_labels,
                     validation_set, validation_labels,
                     batch_size, epochs_count)
    
    display(HTML('<h3>Input layer filters in the plain MLP</h3>'))
    draw_layer_filters(mlp[0])
    
    display(HTML('<h3>DBN training</h3>'))
    train_dbn(dbn, train_set, monitoring_set, batch_size, epochs_count)
    
    for layer in mlp:
        layer.reset()
    
    initialize_mlp(mlp, dbn)
    
    display(HTML('<h3>Finetuning pretrained MLP</h3>'))
    run_mlp_training(mlp,
                     train_set, train_labels,
                     validation_set, validation_labels,
                     batch_size, epochs_count)
    
    display(HTML('<h3>First layer filters in the DBN</h3>'))
    draw_filters(dbn[0])
    
    display(HTML('<h3>Input layer filters in the pretrained & finetuned MLP</h3>'))
    draw_layer_filters(mlp[0])

# %%
VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE
HIDDEN_LAYER_SIZE = 256

BATCH_SIZE = 128
EPOCHS_COUNT = 50

LEARNING_RATE = 0.1
SOFTMAX_LEARNING_RATE = 0.15
MOMENTUM = 0.5
L2_PENALTY = 0.00002

# %% [markdown]
# ### Shallow neural network

# %%
shallow_mlp = [
    Layer(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, sigmoid, sigmoid_derivative, LEARNING_RATE, MOMENTUM, L2_PENALTY),
    Layer(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, sigmoid, sigmoid_derivative, LEARNING_RATE, MOMENTUM, L2_PENALTY),
    Layer(HIDDEN_LAYER_SIZE, 10, softmax, None, SOFTMAX_LEARNING_RATE, MOMENTUM, L2_PENALTY)
]

shallow_dbn = [
    Rbm(mlp_layer.visible_size,
        mlp_layer.hidden_size,
        LEARNING_RATE, MOMENTUM, 0.0, L2_PENALTY) for mlp_layer in shallow_mlp[:-1]
]

compare_pretraining_results(shallow_mlp, shallow_dbn,
                            mnist_train_images, mnist_train_labels,
                            mnist_test_images, mnist_test_labels,
                            monitoring_set,
                            BATCH_SIZE, EPOCHS_COUNT)
# Out:
# <h3>Plain MLP training</h3>
# Epoch 1:	########################################	elapsed: 0.76s, accuracy: 10.10
# Epoch 2:	########################################	elapsed: 0.65s, accuracy: 10.10
# Epoch 3:	########################################	elapsed: 0.66s, accuracy: 8.92
# Epoch 4:	########################################	elapsed: 0.65s, accuracy: 8.92
# Epoch 5:	########################################	elapsed: 0.70s, accuracy: 11.35
# Epoch 6:	########################################	elapsed: 0.66s, accuracy: 15.04
# Epoch 7:	########################################	elapsed: 0.69s, accuracy: 27.19
# Epoch 8:	########################################	elapsed: 0.71s, accuracy: 31.92
# Epoch 9:	########################################	elapsed: 0.70s, accuracy: 33.43
# Epoch 10:	########################################	elapsed: 0.74s, accuracy: 47.20
# Epoch 11:	########################################	elapsed: 0.75s, accuracy: 52.92
# Epoch 12:	########################################	elapsed: 0.66s, accuracy: 58.92
# Epoch 13:	########################################	elapsed: 0.68s, accuracy: 69.78
# Epoch 14:	########################################	elapsed: 0.71s, accuracy: 81.26
# Epoch 15:	########################################	elapsed: 0.66s, accuracy: 84.86
# Epoch 16:	########################################	elapsed: 0.67s, accuracy: 87.04
# Epoch 17:	########################################	elapsed: 0.69s, accuracy: 88.20
# Epoch 18:	########################################	elapsed: 0.70s, accuracy: 89.25
# Epoch 19:	########################################	elapsed: 0.67s, accuracy: 90.09
# Epoch 20:	########################################	elapsed: 0.69s, accuracy: 90.79
# Epoch 21:	########################################	elapsed: 0.68s, accuracy: 91.07
# Epoch 22:	########################################	elapsed: 0.70s, accuracy: 91.44
# Epoch 23:	########################################	elapsed: 0.71s, accuracy: 91.70
# Epoch 24:	########################################	elapsed: 0.70s, accuracy: 91.88
# Epoch 25:	########################################	elapsed: 0.71s, accuracy: 91.94
# Epoch 26:	########################################	elapsed: 0.68s, accuracy: 92.28
# Epoch 27:	########################################	elapsed: 0.65s, accuracy: 92.57
# Epoch 28:	########################################	elapsed: 0.66s, accuracy: 92.71
# Epoch 29:	########################################	elapsed: 0.67s, accuracy: 92.96
# Epoch 30:	########################################	elapsed: 0.66s, accuracy: 93.14
# Epoch 31:	########################################	elapsed: 0.68s, accuracy: 93.15
# Epoch 32:	########################################	elapsed: 0.66s, accuracy: 93.10
# Epoch 33:	########################################	elapsed: 0.79s, accuracy: 93.26
# Epoch 34:	########################################	elapsed: 0.70s, accuracy: 93.62
# Epoch 35:	########################################	elapsed: 0.74s, accuracy: 93.80
# Epoch 36:	########################################	elapsed: 0.61s, accuracy: 93.78
# Epoch 37:	########################################	elapsed: 0.51s, accuracy: 93.76
# Epoch 38:	########################################	elapsed: 0.56s, accuracy: 93.76
# Epoch 39:	########################################	elapsed: 0.54s, accuracy: 93.67
# Epoch 40:	########################################	elapsed: 0.55s, accuracy: 93.50
# Epoch 41:	########################################	elapsed: 0.55s, accuracy: 93.46
# Epoch 42:	########################################	elapsed: 0.52s, accuracy: 93.50
# Epoch 43:	########################################	elapsed: 0.51s, accuracy: 93.55
# Epoch 44:	########################################	elapsed: 0.56s, accuracy: 93.47
# Epoch 45:	########################################	elapsed: 0.52s, accuracy: 93.53
# Epoch 46:	########################################	elapsed: 0.54s, accuracy: 93.53
# Epoch 47:	########################################	elapsed: 0.57s, accuracy: 93.61
# Epoch 48:	########################################	elapsed: 0.53s, accuracy: 93.76
# Epoch 49:	########################################	elapsed: 0.51s, accuracy: 93.58
# Epoch 50:	########################################	elapsed: 0.42s, accuracy: 93.26
# Training finished!
# <h3>Input layer filters in the plain MLP</h3>
# <h3>DBN training</h3>
# Learning layer 0
# Epoch 1:	########################################	elapsed: 0.79s, reconstruction error: 31.85
# Epoch 2:	########################################	elapsed: 0.75s, reconstruction error: 24.92
# Epoch 3:	########################################	elapsed: 0.72s, reconstruction error: 21.45
# Epoch 4:	########################################	elapsed: 0.72s, reconstruction error: 19.06
# Epoch 5:	########################################	elapsed: 0.72s, reconstruction error: 17.81
# Epoch 6:	########################################	elapsed: 0.85s, reconstruction error: 15.39
# Epoch 7:	########################################	elapsed: 0.92s, reconstruction error: 13.40
# Epoch 8:	########################################	elapsed: 0.85s, reconstruction error: 12.43
# Epoch 9:	########################################	elapsed: 0.79s, reconstruction error: 11.83
# Epoch 10:	########################################	elapsed: 0.78s, reconstruction error: 11.43
# Epoch 11:	########################################	elapsed: 0.77s, reconstruction error: 11.14
# Epoch 12:	########################################	elapsed: 0.80s, reconstruction error: 10.70
# Epoch 13:	########################################	elapsed: 0.76s, reconstruction error: 10.40
# Epoch 14:	########################################	elapsed: 0.75s, reconstruction error: 10.34
# Epoch 15:	########################################	elapsed: 0.73s, reconstruction error: 9.99
# Epoch 16:	########################################	elapsed: 0.73s, reconstruction error: 9.87
# Epoch 17:	########################################	elapsed: 0.71s, reconstruction error: 10.00
# Epoch 18:	########################################	elapsed: 0.73s, reconstruction error: 9.74
# Epoch 19:	########################################	elapsed: 0.74s, reconstruction error: 9.45
# Epoch 20:	########################################	elapsed: 0.74s, reconstruction error: 9.42
# Epoch 21:	########################################	elapsed: 0.74s, reconstruction error: 9.56
# Epoch 22:	########################################	elapsed: 0.74s, reconstruction error: 9.37
# Epoch 23:	########################################	elapsed: 0.72s, reconstruction error: 9.35
# Epoch 24:	########################################	elapsed: 0.75s, reconstruction error: 9.30
# Epoch 25:	########################################	elapsed: 0.70s, reconstruction error: 9.36
# Epoch 26:	########################################	elapsed: 0.72s, reconstruction error: 9.27
# Epoch 27:	########################################	elapsed: 0.70s, reconstruction error: 9.13
# Epoch 28:	########################################	elapsed: 0.73s, reconstruction error: 9.19
# Epoch 29:	########################################	elapsed: 0.78s, reconstruction error: 9.12
# Epoch 30:	########################################	elapsed: 0.72s, reconstruction error: 9.02
# Epoch 31:	########################################	elapsed: 0.76s, reconstruction error: 9.04
# Epoch 32:	########################################	elapsed: 0.73s, reconstruction error: 8.96
# Epoch 33:	########################################	elapsed: 0.73s, reconstruction error: 9.05
# Epoch 34:	########################################	elapsed: 0.76s, reconstruction error: 8.92
# Epoch 35:	########################################	elapsed: 0.71s, reconstruction error: 8.87
# Epoch 36:	########################################	elapsed: 0.71s, reconstruction error: 8.96
# Epoch 37:	########################################	elapsed: 0.72s, reconstruction error: 8.83
# Epoch 38:	########################################	elapsed: 0.72s, reconstruction error: 8.74
# Epoch 39:	########################################	elapsed: 0.71s, reconstruction error: 8.80
# Epoch 40:	########################################	elapsed: 0.75s, reconstruction error: 8.70
# Epoch 41:	########################################	elapsed: 0.74s, reconstruction error: 8.73
# Epoch 42:	########################################	elapsed: 0.75s, reconstruction error: 8.83
# Epoch 43:	########################################	elapsed: 0.75s, reconstruction error: 8.60
# Epoch 44:	########################################	elapsed: 0.74s, reconstruction error: 8.49
# Epoch 45:	########################################	elapsed: 0.74s, reconstruction error: 8.67
# Epoch 46:	########################################	elapsed: 0.75s, reconstruction error: 8.70
# Epoch 47:	########################################	elapsed: 0.78s, reconstruction error: 8.54
# Epoch 48:	########################################	elapsed: 0.76s, reconstruction error: 8.57
# Epoch 49:	########################################	elapsed: 0.75s, reconstruction error: 8.63
# Epoch 50:	########################################	elapsed: 0.75s, reconstruction error: 8.57
#
# Learning layer 1
# Epoch 1:	########################################	elapsed: 0.44s, reconstruction error: 19.44
# Epoch 2:	########################################	elapsed: 0.47s, reconstruction error: 14.85
# Epoch 3:	########################################	elapsed: 0.48s, reconstruction error: 12.64
# Epoch 4:	########################################	elapsed: 0.48s, reconstruction error: 11.28
# Epoch 5:	########################################	elapsed: 0.46s, reconstruction error: 10.32
# Epoch 6:	########################################	elapsed: 0.46s, reconstruction error: 8.61
# Epoch 7:	########################################	elapsed: 0.47s, reconstruction error: 7.31
# Epoch 8:	########################################	elapsed: 0.47s, reconstruction error: 6.72
# Epoch 9:	########################################	elapsed: 0.49s, reconstruction error: 6.14
# Epoch 10:	########################################	elapsed: 0.50s, reconstruction error: 5.85
# Epoch 11:	########################################	elapsed: 0.48s, reconstruction error: 5.57
# Epoch 12:	########################################	elapsed: 0.48s, reconstruction error: 5.35
# Epoch 13:	########################################	elapsed: 0.47s, reconstruction error: 5.15
# Epoch 14:	########################################	elapsed: 0.47s, reconstruction error: 5.09
# Epoch 15:	########################################	elapsed: 0.46s, reconstruction error: 5.05
# Epoch 16:	########################################	elapsed: 0.46s, reconstruction error: 4.88
# Epoch 17:	########################################	elapsed: 0.47s, reconstruction error: 4.85
# Epoch 18:	########################################	elapsed: 0.47s, reconstruction error: 4.67
# Epoch 19:	########################################	elapsed: 0.49s, reconstruction error: 4.65
# Epoch 20:	########################################	elapsed: 0.47s, reconstruction error: 4.61
# Epoch 21:	########################################	elapsed: 0.44s, reconstruction error: 4.60
# Epoch 22:	########################################	elapsed: 0.45s, reconstruction error: 4.53
# Epoch 23:	########################################	elapsed: 0.50s, reconstruction error: 4.49
# Epoch 24:	########################################	elapsed: 0.47s, reconstruction error: 4.45
# Epoch 25:	########################################	elapsed: 0.48s, reconstruction error: 4.41
# Epoch 26:	########################################	elapsed: 0.46s, reconstruction error: 4.36
# Epoch 27:	########################################	elapsed: 0.46s, reconstruction error: 4.39
# Epoch 28:	########################################	elapsed: 0.45s, reconstruction error: 4.32
# Epoch 29:	########################################	elapsed: 0.47s, reconstruction error: 4.30
# Epoch 30:	########################################	elapsed: 0.47s, reconstruction error: 4.23
# Epoch 31:	########################################	elapsed: 0.48s, reconstruction error: 4.31
# Epoch 32:	########################################	elapsed: 0.46s, reconstruction error: 4.23
# Epoch 33:	########################################	elapsed: 0.47s, reconstruction error: 4.20
# Epoch 34:	########################################	elapsed: 0.46s, reconstruction error: 4.23
# Epoch 35:	########################################	elapsed: 0.47s, reconstruction error: 4.23
# Epoch 36:	########################################	elapsed: 0.48s, reconstruction error: 4.24
# Epoch 37:	########################################	elapsed: 0.47s, reconstruction error: 4.27
# Epoch 38:	########################################	elapsed: 0.47s, reconstruction error: 4.10
# Epoch 39:	########################################	elapsed: 0.47s, reconstruction error: 4.23
# Epoch 40:	########################################	elapsed: 0.46s, reconstruction error: 4.10
# Epoch 41:	########################################	elapsed: 0.47s, reconstruction error: 4.20
# Epoch 42:	########################################	elapsed: 0.48s, reconstruction error: 4.04
# Epoch 43:	########################################	elapsed: 0.46s, reconstruction error: 4.13
# Epoch 44:	########################################	elapsed: 0.46s, reconstruction error: 4.08
# Epoch 45:	########################################	elapsed: 0.47s, reconstruction error: 4.09
# Epoch 46:	########################################	elapsed: 0.48s, reconstruction error: 4.06
# Epoch 47:	########################################	elapsed: 0.46s, reconstruction error: 4.07
# Epoch 48:	########################################	elapsed: 0.45s, reconstruction error: 3.99
# Epoch 49:	########################################	elapsed: 0.45s, reconstruction error: 4.06
# Epoch 50:	########################################	elapsed: 0.47s, reconstruction error: 3.99
# <h3>Finetuning pretrained MLP</h3>
# Epoch 1:	########################################	elapsed: 0.54s, accuracy: 93.83
# Epoch 2:	########################################	elapsed: 0.51s, accuracy: 95.03
# Epoch 3:	########################################	elapsed: 0.51s, accuracy: 95.59
# Epoch 4:	########################################	elapsed: 0.60s, accuracy: 95.90
# Epoch 5:	########################################	elapsed: 0.57s, accuracy: 96.12
# Epoch 6:	########################################	elapsed: 0.58s, accuracy: 96.36
# Epoch 7:	########################################	elapsed: 0.55s, accuracy: 96.46
# Epoch 8:	########################################	elapsed: 0.52s, accuracy: 96.52
# Epoch 9:	########################################	elapsed: 0.55s, accuracy: 96.56
# Epoch 10:	########################################	elapsed: 0.51s, accuracy: 96.57
# Epoch 11:	########################################	elapsed: 0.50s, accuracy: 96.58
# Epoch 12:	########################################	elapsed: 0.57s, accuracy: 96.61
# Epoch 13:	########################################	elapsed: 0.56s, accuracy: 96.64
# Epoch 14:	########################################	elapsed: 0.56s, accuracy: 96.65
# Epoch 15:	########################################	elapsed: 0.51s, accuracy: 96.68
# Epoch 16:	########################################	elapsed: 0.53s, accuracy: 96.69
# Epoch 17:	########################################	elapsed: 0.53s, accuracy: 96.66
# Epoch 18:	########################################	elapsed: 0.54s, accuracy: 96.71
# Epoch 19:	########################################	elapsed: 0.52s, accuracy: 96.70
# Epoch 20:	########################################	elapsed: 0.51s, accuracy: 96.68
# Epoch 21:	########################################	elapsed: 0.57s, accuracy: 96.70
# Epoch 22:	########################################	elapsed: 0.56s, accuracy: 96.66
# Epoch 23:	########################################	elapsed: 0.58s, accuracy: 96.67
# Epoch 24:	########################################	elapsed: 0.57s, accuracy: 96.68
# Epoch 25:	########################################	elapsed: 0.51s, accuracy: 96.70
# Epoch 26:	########################################	elapsed: 0.53s, accuracy: 96.69
# Epoch 27:	########################################	elapsed: 0.56s, accuracy: 96.71
# Epoch 28:	########################################	elapsed: 0.55s, accuracy: 96.72
# Epoch 29:	########################################	elapsed: 0.54s, accuracy: 96.73
# Epoch 30:	########################################	elapsed: 0.52s, accuracy: 96.75
# Epoch 31:	########################################	elapsed: 0.52s, accuracy: 96.74
# Epoch 32:	########################################	elapsed: 0.57s, accuracy: 96.75
# Epoch 33:	########################################	elapsed: 0.55s, accuracy: 96.74
# Epoch 34:	########################################	elapsed: 0.54s, accuracy: 96.73
# Epoch 35:	########################################	elapsed: 0.52s, accuracy: 96.75
# Epoch 36:	########################################	elapsed: 0.52s, accuracy: 96.76
# Epoch 37:	########################################	elapsed: 0.53s, accuracy: 96.77
# Epoch 38:	########################################	elapsed: 0.61s, accuracy: 96.76
# Epoch 39:	########################################	elapsed: 0.59s, accuracy: 96.77
# Epoch 40:	########################################	elapsed: 0.55s, accuracy: 96.75
# Epoch 41:	########################################	elapsed: 0.57s, accuracy: 96.75
# Epoch 42:	########################################	elapsed: 0.59s, accuracy: 96.76
# Epoch 43:	########################################	elapsed: 0.56s, accuracy: 96.76
# Epoch 44:	########################################	elapsed: 0.51s, accuracy: 96.77
# Epoch 45:	########################################	elapsed: 0.56s, accuracy: 96.78
# Epoch 46:	########################################	elapsed: 0.60s, accuracy: 96.78
# Epoch 47:	########################################	elapsed: 0.54s, accuracy: 96.79
# Epoch 48:	########################################	elapsed: 0.53s, accuracy: 96.80
# Epoch 49:	########################################	elapsed: 0.53s, accuracy: 96.81
# Epoch 50:	########################################	elapsed: 0.53s, accuracy: 96.81
# Training finished!
# <h3>First layer filters in the DBN</h3>
# <h3>Input layer filters in the pretrained & finetuned MLP</h3>

# %% [markdown]
# ### Deep neural network

# %%
deep_mlp = [
    Layer(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, sigmoid, sigmoid_derivative, LEARNING_RATE, MOMENTUM, L2_PENALTY),
    Layer(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, sigmoid, sigmoid_derivative, LEARNING_RATE, MOMENTUM, L2_PENALTY),
    Layer(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, sigmoid, sigmoid_derivative, LEARNING_RATE, MOMENTUM, L2_PENALTY),
    Layer(HIDDEN_LAYER_SIZE, 10, softmax, None, SOFTMAX_LEARNING_RATE, MOMENTUM, L2_PENALTY)
]

deep_dbn = [
    Rbm(mlp_layer.visible_size,
        mlp_layer.hidden_size,
        LEARNING_RATE, MOMENTUM, 0.0, L2_PENALTY) for mlp_layer in deep_mlp[:-1]
]

compare_pretraining_results(deep_mlp, deep_dbn,
                            mnist_train_images, mnist_train_labels,
                            mnist_test_images, mnist_test_labels,
                            monitoring_set,
                            BATCH_SIZE, EPOCHS_COUNT)
# Out:
# <h3>Plain MLP training</h3>
# Epoch 1:	########################################	elapsed: 0.88s, accuracy: 10.10
# Epoch 2:	########################################	elapsed: 0.82s, accuracy: 10.10
# Epoch 3:	########################################	elapsed: 0.81s, accuracy: 8.92
# Epoch 4:	########################################	elapsed: 0.74s, accuracy: 8.92
# Epoch 5:	########################################	elapsed: 0.86s, accuracy: 11.35
# Epoch 6:	########################################	elapsed: 0.76s, accuracy: 9.74
# Epoch 7:	########################################	elapsed: 0.82s, accuracy: 9.74
# Epoch 8:	########################################	elapsed: 0.78s, accuracy: 14.91
# Epoch 9:	########################################	elapsed: 0.80s, accuracy: 14.09
# Epoch 10:	########################################	elapsed: 0.82s, accuracy: 13.86
# Epoch 11:	########################################	elapsed: 0.82s, accuracy: 14.59
# Epoch 12:	########################################	elapsed: 0.77s, accuracy: 25.21
# Epoch 13:	########################################	elapsed: 0.76s, accuracy: 29.98
# Epoch 14:	########################################	elapsed: 0.80s, accuracy: 29.60
# Epoch 15:	########################################	elapsed: 0.80s, accuracy: 30.78
# Epoch 16:	########################################	elapsed: 0.90s, accuracy: 32.80
# Epoch 17:	########################################	elapsed: 0.83s, accuracy: 34.97
# Epoch 18:	########################################	elapsed: 0.80s, accuracy: 37.97
# Epoch 19:	########################################	elapsed: 0.79s, accuracy: 39.82
# Epoch 20:	########################################	elapsed: 0.89s, accuracy: 41.26
# Epoch 21:	########################################	elapsed: 0.78s, accuracy: 42.66
# Epoch 22:	########################################	elapsed: 0.73s, accuracy: 44.20
# Epoch 23:	########################################	elapsed: 0.88s, accuracy: 45.94
# Epoch 24:	########################################	elapsed: 0.82s, accuracy: 47.91
# Epoch 25:	########################################	elapsed: 0.73s, accuracy: 50.07
# Epoch 26:	########################################	elapsed: 0.73s, accuracy: 51.93
# Epoch 27:	########################################	elapsed: 0.92s, accuracy: 53.18
# Epoch 28:	########################################	elapsed: 0.79s, accuracy: 54.63
# Epoch 29:	########################################	elapsed: 0.81s, accuracy: 55.50
# Epoch 30:	########################################	elapsed: 0.77s, accuracy: 56.66
# Epoch 31:	########################################	elapsed: 0.74s, accuracy: 57.57
# Epoch 32:	########################################	elapsed: 0.80s, accuracy: 58.37
# Epoch 33:	########################################	elapsed: 0.77s, accuracy: 58.96
# Epoch 34:	########################################	elapsed: 0.78s, accuracy: 59.75
# Epoch 35:	########################################	elapsed: 0.77s, accuracy: 61.35
# Epoch 36:	########################################	elapsed: 0.80s, accuracy: 72.25
# Epoch 37:	########################################	elapsed: 0.76s, accuracy: 79.16
# Epoch 38:	########################################	elapsed: 0.84s, accuracy: 82.25
# Epoch 39:	########################################	elapsed: 0.78s, accuracy: 83.97
# Epoch 40:	########################################	elapsed: 0.83s, accuracy: 84.97
# Epoch 41:	########################################	elapsed: 0.85s, accuracy: 85.62
# Epoch 42:	########################################	elapsed: 0.83s, accuracy: 85.92
# Epoch 43:	########################################	elapsed: 0.83s, accuracy: 85.76
# Epoch 44:	########################################	elapsed: 0.84s, accuracy: 85.34
# Epoch 45:	########################################	elapsed: 0.87s, accuracy: 84.85
# Epoch 46:	########################################	elapsed: 0.85s, accuracy: 85.07
# Epoch 47:	########################################	elapsed: 0.78s, accuracy: 85.77
# Epoch 48:	########################################	elapsed: 0.68s, accuracy: 86.37
# Epoch 49:	########################################	elapsed: 0.78s, accuracy: 86.95
# Epoch 50:	########################################	elapsed: 0.81s, accuracy: 88.15
# Training finished!
# <h3>Input layer filters in the plain MLP</h3>
# <h3>DBN training</h3>
# Learning layer 0
# Epoch 1:	########################################	elapsed: 0.75s, reconstruction error: 31.48
# Epoch 2:	########################################	elapsed: 0.73s, reconstruction error: 24.65
# Epoch 3:	########################################	elapsed: 0.72s, reconstruction error: 21.35
# Epoch 4:	########################################	elapsed: 0.70s, reconstruction error: 19.12
# Epoch 5:	########################################	elapsed: 0.72s, reconstruction error: 17.69
# Epoch 6:	########################################	elapsed: 0.74s, reconstruction error: 15.15
# Epoch 7:	########################################	elapsed: 0.70s, reconstruction error: 13.63
# Epoch 8:	########################################	elapsed: 0.70s, reconstruction error: 12.43
# Epoch 9:	########################################	elapsed: 0.71s, reconstruction error: 11.66
# Epoch 10:	########################################	elapsed: 0.69s, reconstruction error: 11.26
# Epoch 11:	########################################	elapsed: 0.71s, reconstruction error: 10.92
# Epoch 12:	########################################	elapsed: 0.72s, reconstruction error: 10.77
# Epoch 13:	########################################	elapsed: 0.74s, reconstruction error: 10.64
# Epoch 14:	########################################	elapsed: 0.73s, reconstruction error: 10.31
# Epoch 15:	########################################	elapsed: 0.74s, reconstruction error: 10.11
# Epoch 16:	########################################	elapsed: 0.74s, reconstruction error: 10.02
# Epoch 17:	########################################	elapsed: 0.72s, reconstruction error: 9.87
# Epoch 18:	########################################	elapsed: 0.74s, reconstruction error: 9.93
# Epoch 19:	########################################	elapsed: 0.72s, reconstruction error: 9.70
# Epoch 20:	########################################	elapsed: 0.71s, reconstruction error: 9.71
# Epoch 21:	########################################	elapsed: 0.74s, reconstruction error: 9.60
# Epoch 22:	########################################	elapsed: 0.74s, reconstruction error: 9.54
# Epoch 23:	########################################	elapsed: 0.73s, reconstruction error: 9.33
# Epoch 24:	########################################	elapsed: 0.73s, reconstruction error: 9.27
# Epoch 25:	########################################	elapsed: 0.72s, reconstruction error: 9.31
# Epoch 26:	########################################	elapsed: 0.74s, reconstruction error: 9.22
# Epoch 27:	########################################	elapsed: 0.74s, reconstruction error: 9.26
# Epoch 28:	########################################	elapsed: 0.72s, reconstruction error: 9.18
# Epoch 29:	########################################	elapsed: 0.72s, reconstruction error: 9.25
# Epoch 30:	########################################	elapsed: 0.72s, reconstruction error: 9.06
# Epoch 31:	########################################	elapsed: 0.71s, reconstruction error: 9.04
# Epoch 32:	########################################	elapsed: 0.72s, reconstruction error: 8.90
# Epoch 33:	########################################	elapsed: 0.72s, reconstruction error: 8.91
# Epoch 34:	########################################	elapsed: 0.71s, reconstruction error: 8.98
# Epoch 35:	########################################	elapsed: 0.72s, reconstruction error: 8.85
# Epoch 36:	########################################	elapsed: 0.71s, reconstruction error: 8.94
# Epoch 37:	########################################	elapsed: 0.72s, reconstruction error: 8.93
# Epoch 38:	########################################	elapsed: 0.74s, reconstruction error: 8.78
# Epoch 39:	########################################	elapsed: 0.71s, reconstruction error: 8.85
# Epoch 40:	########################################	elapsed: 0.75s, reconstruction error: 8.86
# Epoch 41:	########################################	elapsed: 0.76s, reconstruction error: 8.70
# Epoch 42:	########################################	elapsed: 0.73s, reconstruction error: 8.87
# Epoch 43:	########################################	elapsed: 0.70s, reconstruction error: 8.62
# Epoch 44:	########################################	elapsed: 0.74s, reconstruction error: 8.75
# Epoch 45:	########################################	elapsed: 0.74s, reconstruction error: 8.65
# Epoch 46:	########################################	elapsed: 0.71s, reconstruction error: 8.66
# Epoch 47:	########################################	elapsed: 0.73s, reconstruction error: 8.60
# Epoch 48:	########################################	elapsed: 0.73s, reconstruction error: 8.61
# Epoch 49:	########################################	elapsed: 0.72s, reconstruction error: 8.53
# Epoch 50:	########################################	elapsed: 0.76s, reconstruction error: 8.66
#
# Learning layer 1
# Epoch 1:	########################################	elapsed: 0.47s, reconstruction error: 18.90
# Epoch 2:	########################################	elapsed: 0.46s, reconstruction error: 14.64
# Epoch 3:	########################################	elapsed: 0.46s, reconstruction error: 12.71
# Epoch 4:	########################################	elapsed: 0.46s, reconstruction error: 11.40
# Epoch 5:	########################################	elapsed: 0.48s, reconstruction error: 10.31
# Epoch 6:	########################################	elapsed: 0.47s, reconstruction error: 8.47
# Epoch 7:	########################################	elapsed: 0.48s, reconstruction error: 7.29
# Epoch 8:	########################################	elapsed: 0.44s, reconstruction error: 6.65
# Epoch 9:	########################################	elapsed: 0.45s, reconstruction error: 6.22
# Epoch 10:	########################################	elapsed: 0.45s, reconstruction error: 5.82
# Epoch 11:	########################################	elapsed: 0.50s, reconstruction error: 5.63
# Epoch 12:	########################################	elapsed: 0.47s, reconstruction error: 5.47
# Epoch 13:	########################################	elapsed: 0.46s, reconstruction error: 5.26
# Epoch 14:	########################################	elapsed: 0.47s, reconstruction error: 5.10
# Epoch 15:	########################################	elapsed: 0.46s, reconstruction error: 5.04
# Epoch 16:	########################################	elapsed: 0.45s, reconstruction error: 4.88
# Epoch 17:	########################################	elapsed: 0.47s, reconstruction error: 4.83
# Epoch 18:	########################################	elapsed: 0.48s, reconstruction error: 4.74
# Epoch 19:	########################################	elapsed: 0.50s, reconstruction error: 4.66
# Epoch 20:	########################################	elapsed: 0.49s, reconstruction error: 4.61
# Epoch 21:	########################################	elapsed: 0.44s, reconstruction error: 4.65
# Epoch 22:	########################################	elapsed: 0.46s, reconstruction error: 4.45
# Epoch 23:	########################################	elapsed: 0.46s, reconstruction error: 4.50
# Epoch 24:	########################################	elapsed: 0.47s, reconstruction error: 4.47
# Epoch 25:	########################################	elapsed: 0.47s, reconstruction error: 4.39
# Epoch 26:	########################################	elapsed: 0.49s, reconstruction error: 4.35
# Epoch 27:	########################################	elapsed: 0.44s, reconstruction error: 4.31
# Epoch 28:	########################################	elapsed: 0.46s, reconstruction error: 4.33
# Epoch 29:	########################################	elapsed: 0.45s, reconstruction error: 4.27
# Epoch 30:	########################################	elapsed: 0.47s, reconstruction error: 4.39
# Epoch 31:	########################################	elapsed: 0.48s, reconstruction error: 4.28
# Epoch 32:	########################################	elapsed: 0.45s, reconstruction error: 4.18
# Epoch 33:	########################################	elapsed: 0.45s, reconstruction error: 4.22
# Epoch 34:	########################################	elapsed: 0.47s, reconstruction error: 4.15
# Epoch 35:	########################################	elapsed: 0.47s, reconstruction error: 4.30
# Epoch 36:	########################################	elapsed: 0.48s, reconstruction error: 4.21
# Epoch 37:	########################################	elapsed: 0.45s, reconstruction error: 4.19
# Epoch 38:	########################################	elapsed: 0.46s, reconstruction error: 4.24
# Epoch 39:	########################################	elapsed: 0.45s, reconstruction error: 4.10
# Epoch 40:	########################################	elapsed: 0.45s, reconstruction error: 4.20
# Epoch 41:	########################################	elapsed: 0.45s, reconstruction error: 4.15
# Epoch 42:	########################################	elapsed: 0.45s, reconstruction error: 4.04
# Epoch 43:	########################################	elapsed: 0.47s, reconstruction error: 4.05
# Epoch 44:	########################################	elapsed: 0.50s, reconstruction error: 4.02
# Epoch 45:	########################################	elapsed: 0.45s, reconstruction error: 4.15
# Epoch 46:	########################################	elapsed: 0.47s, reconstruction error: 4.06
# Epoch 47:	########################################	elapsed: 0.46s, reconstruction error: 4.09
# Epoch 48:	########################################	elapsed: 0.48s, reconstruction error: 4.06
# Epoch 49:	########################################	elapsed: 0.48s, reconstruction error: 4.05
# Epoch 50:	########################################	elapsed: 0.48s, reconstruction error: 4.08
#
# Learning layer 2
# Epoch 1:	########################################	elapsed: 0.51s, reconstruction error: 15.44
# Epoch 2:	########################################	elapsed: 0.53s, reconstruction error: 11.09
# Epoch 3:	########################################	elapsed: 0.48s, reconstruction error: 9.25
# Epoch 4:	########################################	elapsed: 0.48s, reconstruction error: 8.08
# Epoch 5:	########################################	elapsed: 0.54s, reconstruction error: 7.20
# Epoch 6:	########################################	elapsed: 0.51s, reconstruction error: 5.81
# Epoch 7:	########################################	elapsed: 0.49s, reconstruction error: 4.94
# Epoch 8:	########################################	elapsed: 0.50s, reconstruction error: 4.54
# Epoch 9:	########################################	elapsed: 0.51s, reconstruction error: 4.23
# Epoch 10:	########################################	elapsed: 0.51s, reconstruction error: 3.94
# Epoch 11:	########################################	elapsed: 0.49s, reconstruction error: 3.92
# Epoch 12:	########################################	elapsed: 0.51s, reconstruction error: 3.81
# Epoch 13:	########################################	elapsed: 0.53s, reconstruction error: 3.66
# Epoch 14:	########################################	elapsed: 0.50s, reconstruction error: 3.61
# Epoch 15:	########################################	elapsed: 0.48s, reconstruction error: 3.49
# Epoch 16:	########################################	elapsed: 0.49s, reconstruction error: 3.54
# Epoch 17:	########################################	elapsed: 0.48s, reconstruction error: 3.52
# Epoch 18:	########################################	elapsed: 0.47s, reconstruction error: 3.40
# Epoch 19:	########################################	elapsed: 0.54s, reconstruction error: 3.34
# Epoch 20:	########################################	elapsed: 0.50s, reconstruction error: 3.34
# Epoch 21:	########################################	elapsed: 0.52s, reconstruction error: 3.24
# Epoch 22:	########################################	elapsed: 0.50s, reconstruction error: 3.25
# Epoch 23:	########################################	elapsed: 0.49s, reconstruction error: 3.23
# Epoch 24:	########################################	elapsed: 0.49s, reconstruction error: 3.18
# Epoch 25:	########################################	elapsed: 0.48s, reconstruction error: 3.15
# Epoch 26:	########################################	elapsed: 0.51s, reconstruction error: 3.18
# Epoch 27:	########################################	elapsed: 0.51s, reconstruction error: 3.11
# Epoch 28:	########################################	elapsed: 0.50s, reconstruction error: 3.12
# Epoch 29:	########################################	elapsed: 0.51s, reconstruction error: 3.12
# Epoch 30:	########################################	elapsed: 0.49s, reconstruction error: 3.18
# Epoch 31:	########################################	elapsed: 0.48s, reconstruction error: 3.02
# Epoch 32:	########################################	elapsed: 0.47s, reconstruction error: 3.06
# Epoch 33:	########################################	elapsed: 0.51s, reconstruction error: 3.13
# Epoch 34:	########################################	elapsed: 0.49s, reconstruction error: 3.02
# Epoch 35:	########################################	elapsed: 0.51s, reconstruction error: 3.03
# Epoch 36:	########################################	elapsed: 0.50s, reconstruction error: 3.05
# Epoch 37:	########################################	elapsed: 0.48s, reconstruction error: 3.04
# Epoch 38:	########################################	elapsed: 0.50s, reconstruction error: 3.04
# Epoch 39:	########################################	elapsed: 0.54s, reconstruction error: 2.96
# Epoch 40:	########################################	elapsed: 0.53s, reconstruction error: 2.98
# Epoch 41:	########################################	elapsed: 0.49s, reconstruction error: 2.98
# Epoch 42:	########################################	elapsed: 0.52s, reconstruction error: 3.01
# Epoch 43:	########################################	elapsed: 0.55s, reconstruction error: 2.99
# Epoch 44:	########################################	elapsed: 0.53s, reconstruction error: 3.03
# Epoch 45:	########################################	elapsed: 0.49s, reconstruction error: 2.97
# Epoch 46:	########################################	elapsed: 0.47s, reconstruction error: 2.98
# Epoch 47:	########################################	elapsed: 0.51s, reconstruction error: 2.89
# Epoch 48:	########################################	elapsed: 0.48s, reconstruction error: 3.02
# Epoch 49:	########################################	elapsed: 0.54s, reconstruction error: 2.97
# Epoch 50:	########################################	elapsed: 0.48s, reconstruction error: 2.93
# <h3>Finetuning pretrained MLP</h3>
# Epoch 1:	########################################	elapsed: 0.69s, accuracy: 94.05
# Epoch 2:	########################################	elapsed: 0.73s, accuracy: 94.82
# Epoch 3:	########################################	elapsed: 0.71s, accuracy: 95.35
# Epoch 4:	########################################	elapsed: 0.78s, accuracy: 95.72
# Epoch 5:	########################################	elapsed: 0.79s, accuracy: 95.88
# Epoch 6:	########################################	elapsed: 0.73s, accuracy: 96.00
# Epoch 7:	########################################	elapsed: 0.76s, accuracy: 96.15
# Epoch 8:	########################################	elapsed: 0.78s, accuracy: 96.17
# Epoch 9:	########################################	elapsed: 0.65s, accuracy: 96.24
# Epoch 10:	########################################	elapsed: 0.72s, accuracy: 96.34
# Epoch 11:	########################################	elapsed: 0.72s, accuracy: 96.40
# Epoch 12:	########################################	elapsed: 0.75s, accuracy: 96.52
# Epoch 13:	########################################	elapsed: 0.75s, accuracy: 96.60
# Epoch 14:	########################################	elapsed: 0.67s, accuracy: 96.68
# Epoch 15:	########################################	elapsed: 0.72s, accuracy: 96.73
# Epoch 16:	########################################	elapsed: 0.72s, accuracy: 96.78
# Epoch 17:	########################################	elapsed: 0.74s, accuracy: 96.81
# Epoch 18:	########################################	elapsed: 0.74s, accuracy: 96.83
# Epoch 19:	########################################	elapsed: 0.69s, accuracy: 96.87
# Epoch 20:	########################################	elapsed: 0.74s, accuracy: 96.92
# Epoch 21:	########################################	elapsed: 0.77s, accuracy: 96.92
# Epoch 22:	########################################	elapsed: 0.74s, accuracy: 96.95
# Epoch 23:	########################################	elapsed: 0.78s, accuracy: 96.95
# Epoch 24:	########################################	elapsed: 0.73s, accuracy: 96.95
# Epoch 25:	########################################	elapsed: 0.65s, accuracy: 96.95
# Epoch 26:	########################################	elapsed: 0.76s, accuracy: 96.95
# Epoch 27:	########################################	elapsed: 0.73s, accuracy: 96.95
# Epoch 28:	########################################	elapsed: 0.81s, accuracy: 96.97
# Epoch 29:	########################################	elapsed: 0.72s, accuracy: 97.02
# Epoch 30:	########################################	elapsed: 0.73s, accuracy: 97.05
# Epoch 31:	########################################	elapsed: 0.71s, accuracy: 97.05
# Epoch 32:	########################################	elapsed: 0.76s, accuracy: 97.04
# Epoch 33:	########################################	elapsed: 0.75s, accuracy: 97.03
# Epoch 34:	########################################	elapsed: 0.76s, accuracy: 97.05
# Epoch 35:	########################################	elapsed: 0.81s, accuracy: 97.03
# Epoch 36:	########################################	elapsed: 0.71s, accuracy: 97.04
# Epoch 37:	########################################	elapsed: 0.72s, accuracy: 97.06
# Epoch 38:	########################################	elapsed: 0.76s, accuracy: 97.07
# Epoch 39:	########################################	elapsed: 0.75s, accuracy: 97.07
# Epoch 40:	########################################	elapsed: 0.72s, accuracy: 97.08
# Epoch 41:	########################################	elapsed: 0.75s, accuracy: 97.09
# Epoch 42:	########################################	elapsed: 0.78s, accuracy: 97.10
# Epoch 43:	########################################	elapsed: 0.75s, accuracy: 97.10
# Epoch 44:	########################################	elapsed: 0.72s, accuracy: 97.09
# Epoch 45:	########################################	elapsed: 0.76s, accuracy: 97.10
# Epoch 46:	########################################	elapsed: 0.76s, accuracy: 97.10
# Epoch 47:	########################################	elapsed: 0.75s, accuracy: 97.10
# Epoch 48:	########################################	elapsed: 0.69s, accuracy: 97.12
# Epoch 49:	########################################	elapsed: 0.82s, accuracy: 97.12
# Epoch 50:	########################################	elapsed: 0.71s, accuracy: 97.13
# Training finished!
# <h3>First layer filters in the DBN</h3>
# <h3>Input layer filters in the pretrained & finetuned MLP</h3>
