# %%
import numpy as np
import matplotlib.pyplot as plt
# import mkl

# mkl.set_num_threads(2)
np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix):
    return np.concatenate((matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=1)

def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def chunks(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]
    
    space_between_tiles = 2
    img_matrix = np.empty(shape=(rows_count * (tile_height + space_between_tiles) - space_between_tiles,  
                                 cols_count * (tile_width + space_between_tiles) - space_between_tiles))
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            img_matrix[x_0:x_0 + tile_height, y_0:y_0 + tile_width] = examples[r, c]
    
    plt.matshow(img_matrix, cmap='gray', interpolation='none')
    plt.axis('off')
    plt.show()

# %% [markdown]
# # MNIST dataset

# %%
import mnist
digits = np.reshape(mnist.train_images()[:12*24], newshape=(12, 24, 28, 28))
tiles(digits)

# %% [markdown]
# # Restricted Boltzmann Machine & Contrastive Divergence algorithm

# %%
def sigmoid(matrix):
    return 1.0 / (1.0 + np.exp(-matrix))

class Rbm:
    def __init__(self, visible_size, hidden_size, learning_rate):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        self.learning_rate = learning_rate
        
        self.reset()
        
    def reset(self):
        self.W = np.random.normal(scale=0.01,
                                  size=(self.visible_size+1, self.hidden_size+1)).astype(np.float32)
        self.W[:, -1] = 0.0
        self.W[-1, :] = 0.0

# %% [markdown]
# ## Algorytm Contrastive Divergence
#
# $\newcommand{\vect}[1]{\mathbf{#1}}$
# W sieci RBM gradient funkcji kosztu względem wag wyznaczamy zgodnie ze wzorem:
#
# $\frac{\delta}{\delta w_{ij}} -\log P(\vect{v}) = -\mathbf{E}[v_i h_j \vert \vect{v}] + \mathbf{E}[v_i h_j]$
#
# #### Faza pozytywna - odpowiada za część $\mathbf{E}[v_i h_j \vert \vect{v}]$
#
# Tą część gradientu wyznaczamy przez wyliczenie iloczynów $v_i h_j$ pomiędzy elementami wektora obserwacji ($v_i$) a prawdopodobieństwami aktywacji w warstwie ukrytej ($h_j$). Operację tą możemy zapisać w postaci zwektoryzowanej jako:
#
# $\nabla_P = \vect{v}^T\sigma(\vect{vW})$
#
# #### Faza negatywna - odpowiada za część $\mathbf{E}[v_i h_j]$
#
# Rozpoczynamy od prawdopodobieństw aktywacji neuronów w warstwie ukrytej, które zostały wyznaczone w fazie pozytywnej. Na ich podstawie losujemy próbkę aktywacji w warstwie ukrytej:
#
# $\vect{h} = \sigma (\vect{vW}) > [rand_1, rand_2, \dots, rand_m]$
#
# Następnie losujemy próbkę aktywacji w warstwie widocznej:
#
# $\vect{v}_1 = \sigma (\vect{hW}^T) > [rand_1, rand_2, \dots, rand_n]$
#
# Aby wyznaczyć *fantazję* sieci RBM, powyższe próbki losujemy (naprzemiennie) $k$ razy (gdzie $k$ to parametr algorytmu CD-*k*):
#
# $\vect{h}_{k-1} = \sigma (\vect{v}_{k-1}\vect{W}) > [rand_1, rand_2, \dots, rand_m]$,
# $\vect{v}_k = \sigma (\vect{h}_{k-1}\vect{W}^T) > [rand_1, rand_2, \dots, rand_n]$
#
# Część negatywną gradientu wyznaczamy poprzez wyliczenie iloczynów $v_{k_i} h_j$ pomiędzy elementami wektora *fantazji* RBM ($v_{k_i}$) a prawdopodobieństwami aktywacji w warstwie ukrytej wyliczonymi dla tejże *fantazji* ($h_j$). Operację tą możemy zapisać w postaci zwektoryzowanej jako:
#
# $\nabla_N = \vect{v}_k^T\sigma(\vect{v}_k\vect{W})$
#
#
# #### Aktualizacja macierzy wag RBM
#
# Uczymy stochastycznym spadkiem wzdłuż gradientu:
#
# $\phi_{t+1} \leftarrow \phi_t - \epsilon \nabla$
#
# co dla gradientu RBM daje:
#
# $W_{t+1} \leftarrow W_t + \epsilon \nabla_P - \epsilon \nabla_N$

# %%
# equations from the markdown above...
 
get_hidden = lambda visible, W: sigmoid(visible @ W[:, :-1])
get_visible = lambda hidden, W: sigmoid(hidden @ W[:-1, :].T)
get_grad = lambda hidden, visible: (visible.T @ hidden)
activation_proba = lambda neurons: neurons > rand(*neurons.shape)

# %%
def cdk(rbm, minibatch, k=1):
    observations_count = minibatch.shape[0]

    positive_visible = minibatch
    negative_visible = append_ones(zeros(observations_count, rbm.visible_size))

    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_hidden = append_ones(zeros(observations_count, rbm.hidden_size))

    # positive phase
    positive_hidden[:, :-1] = get_hidden(positive_visible, rbm.W)
    grad_p = get_grad(positive_hidden, positive_visible) / observations_count

    # negative phase
    negative_hidden[:, :-1] = activation_proba(positive_hidden[:, :-1])
    negative_visible[:, :-1] = activation_proba(get_visible(negative_hidden, rbm.W))

    for _ in range(k - 1):
        negative_hidden[:, :-1] = activation_proba(get_hidden(negative_visible, rbm.W))
        negative_visible[:, :-1] = activation_proba(get_visible(negative_hidden, rbm.W))

    negative_hidden[:, :-1] = get_hidden(negative_visible, rbm.W)
    grad_n = get_grad(negative_hidden, negative_visible) / observations_count

    # update weight
    rbm.W = rbm.W + rbm.learning_rate * grad_p - rbm.learning_rate * grad_n

# %% [markdown]
# ### RBM reconstruction error

# %%
def reconstuction_error(rbm, minibatch):
    observations_count = minibatch.shape[0]
    
    visible = zeros(observations_count, rbm.visible_size)
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))

    hidden[:, :-1] = activation_proba(get_hidden(minibatch, rbm.W))
    visible[:, :-1] = get_visible(hidden, rbm.W)
    
    error = np.sum((minibatch[:, :-1] - visible) ** 2) / observations_count

    return error

# %% [markdown]
# # RBM Training

# %%
import time

DATASET_SIZE = 20000 # 60000 for whole dataset
DIGIT_SIZE = 28

VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE
HIDDEN_LAYER_SIZE = 128
LEARNING_RATE = 0.1

mnist_train = mnist.train_images().astype(np.float32) / 255.0
np.random.shuffle(mnist_train)
dataset = np.reshape(mnist_train[:DATASET_SIZE], newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
dataset = append_ones(dataset)

monitoring_indeces = np.random.choice(DATASET_SIZE, 256, replace=False)
monitoring_set = dataset[monitoring_indeces]

rbm = Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, LEARNING_RATE)

# %%
def draw_filters(rbm):
    filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
    filters = np.clip(filters, -1, 1)
    tiles(filters)

# %%
draw_filters(rbm)

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 50

def train_epoch(rbm, dataset):
    batches_limit = dataset.shape[0] / BATCH_SIZE
    for batch_idx, batch in enumerate(chunks(dataset, BATCH_SIZE)):
        cdk(rbm, batch)
        if batch_idx % round(batches_limit / 50) == 0: print("#", end="")

rbm.reset()
for epoch in range(EPOCHS_COUNT):
    print("Epoch {}:".format(epoch + 1),  end="\t")
    
    start_time = time.time()
    train_epoch(rbm, dataset)
    
    elapsed = time.time() - start_time
    error = reconstuction_error(rbm, monitoring_set)
    print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))
    
print("Training finished!")
# Out:
# Epoch 1:	#####################################################
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 18
#      15     train_epoch(rbm, dataset)
#      17     elapsed = time.time() - start_time
# ---> 18     error = reconstuction_error(rbm, monitoring_set)
#      19     print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))
#      21 print("Training finished!")
#
# Cell In[7], line 8, in reconstuction_error(rbm, minibatch)
#       5 hidden = append_ones(zeros(observations_count, rbm.hidden_size))
#       7 hidden[:, :-1] = activation_proba(get_hidden(minibatch, rbm.W))
# ----> 8 visible[:, :-1] = get_visible(hidden, rbm.W)
#      10 error = np.sum((minibatch - visible) ** 2) / observations_count
#      12 return error
#
# ValueError: could not broadcast input array from shape (256,784) into shape (256,783)

# %%
draw_filters(rbm)

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 50

def train_epoch(rbm, dataset):
    batches_limit = dataset.shape[0] / BATCH_SIZE
    for batch_idx, batch in enumerate(chunks(dataset, BATCH_SIZE)):
        cdk(rbm, batch, k=5)
        if batch_idx % round(batches_limit / 50) == 0: print("#", end="")

rbm.reset()
for epoch in range(EPOCHS_COUNT):
    print("Epoch {}:".format(epoch + 1),  end="\t")
    
    start_time = time.time()
    train_epoch(rbm, dataset)
    
    elapsed = time.time() - start_time
    error = reconstuction_error(rbm, monitoring_set)
    print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))
    
print("Training finished!")
# Out:
# Epoch 1:	#####################################################	elapsed: 3.77s, reconstruction error: 33.97
# Epoch 2:	#####################################################	elapsed: 3.42s, reconstruction error: 26.42
# Epoch 3:	#####################################################	elapsed: 3.41s, reconstruction error: 23.18
# Epoch 4:	#####################################################	elapsed: 3.39s, reconstruction error: 21.27
# Epoch 5:	#####################################################	elapsed: 3.36s, reconstruction error: 19.59
# Epoch 6:	#####################################################	elapsed: 3.30s, reconstruction error: 18.68
# Epoch 7:	#####################################################	elapsed: 3.27s, reconstruction error: 17.96
# Epoch 8:	#####################################################	elapsed: 3.22s, reconstruction error: 17.13
# Epoch 9:	#####################################################	elapsed: 3.23s, reconstruction error: 16.48
# Epoch 10:	#####################################################	elapsed: 3.25s, reconstruction error: 16.12
# Epoch 11:	#####################################################	elapsed: 3.24s, reconstruction error: 15.60
# Epoch 12:	#####################################################	elapsed: 3.31s, reconstruction error: 15.21
# Epoch 13:	#####################################################	elapsed: 3.33s, reconstruction error: 14.94
# Epoch 14:	#####################################################	elapsed: 3.34s, reconstruction error: 14.93
# Epoch 15:	#####################################################	elapsed: 3.42s, reconstruction error: 14.42
# Epoch 16:	#####################################################	elapsed: 3.32s, reconstruction error: 14.15
# Epoch 17:	#####################################################	elapsed: 3.26s, reconstruction error: 14.22
# Epoch 18:	#####################################################	elapsed: 3.34s, reconstruction error: 13.71
# Epoch 19:	#####################################################	elapsed: 3.53s, reconstruction error: 13.58
# Epoch 20:	#####################################################	elapsed: 3.40s, reconstruction error: 13.46
# Epoch 21:	#####################################################	elapsed: 3.52s, reconstruction error: 13.43
# Epoch 22:	#####################################################	elapsed: 3.30s, reconstruction error: 13.06
# Epoch 23:	#####################################################	elapsed: 3.26s, reconstruction error: 13.05
# Epoch 24:	#####################################################	elapsed: 3.32s, reconstruction error: 12.94
# Epoch 25:	#####################################################	elapsed: 3.39s, reconstruction error: 12.80
# Epoch 26:	#####################################################	elapsed: 3.30s, reconstruction error: 12.69
# Epoch 27:	#####################################################	elapsed: 3.42s, reconstruction error: 12.44
# Epoch 28:	#####################################################	elapsed: 3.38s, reconstruction error: 12.42
# Epoch 29:	#####################################################	elapsed: 3.27s, reconstruction error: 12.25
# Epoch 30:	#####################################################	elapsed: 3.24s, reconstruction error: 12.26
# Epoch 31:	#####################################################	elapsed: 3.25s, reconstruction error: 12.20
# Epoch 32:	#####################################################	elapsed: 3.31s, reconstruction error: 12.15
# Epoch 33:	#####################################################	elapsed: 3.32s, reconstruction error: 11.92
# Epoch 34:	#####################################################	elapsed: 3.41s, reconstruction error: 11.91
# Epoch 35:	#####################################################	elapsed: 3.29s, reconstruction error: 11.68
# Epoch 36:	#####################################################	elapsed: 3.41s, reconstruction error: 11.66
# Epoch 37:	#####################################################	elapsed: 3.33s, reconstruction error: 11.69
# Epoch 38:	#####################################################	elapsed: 3.37s, reconstruction error: 11.62
# Epoch 39:	#####################################################	elapsed: 3.41s, reconstruction error: 11.50
# Epoch 40:	#####################################################	elapsed: 3.27s, reconstruction error: 11.56
# Epoch 41:	#####################################################	elapsed: 3.38s, reconstruction error: 11.52
# Epoch 42:	#####################################################	elapsed: 3.41s, reconstruction error: 11.31
# Epoch 43:	#####################################################	elapsed: 3.49s, reconstruction error: 11.37
# Epoch 44:	#####################################################	elapsed: 3.28s, reconstruction error: 11.29
# Epoch 45:	#####################################################	elapsed: 3.40s, reconstruction error: 11.12
# Epoch 46:	#####################################################	elapsed: 3.35s, reconstruction error: 11.15
# Epoch 47:	#####################################################	elapsed: 3.40s, reconstruction error: 11.09
# Epoch 48:	#####################################################	elapsed: 3.39s, reconstruction error: 11.12
# Epoch 49:	#####################################################	elapsed: 3.42s, reconstruction error: 11.05
# Epoch 50:	#####################################################	elapsed: 3.36s, reconstruction error: 11.00
# Training finished!

# %%
draw_filters(rbm)
